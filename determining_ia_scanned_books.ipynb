# %% [markdown]
# # Determining IA Scanned books
# ## Problem
# Internet Archive's text archiving, containing scanned books and documents, has approximately 38 million records in it by 2023-07. However, to date the scannning labor team has only been able to identify 9 million texts by querying via scanning center: [insert he link]
# - this dataset was accumulated first by querying for all scan ids from known scanning centers unearthed through analyzing Open Library's data dumps (which contains 2 million records scanned at 64 unique centers) and cross checking these with texts included in major subcollections of the IA text collection (American Libraries, Canadian Libraries, Books by Language, etc.)
# - Through querying collections, we discovered that many of the books in IA's records were not scanned at IA scanning centers. Rather, individual users uploaded public domain books scanned for other mass digitizaiton projects including Google Books, HathiTrust, and Project Gutenberg.
#
#
# The goal of this jupyter notebook is to try and come up with a more-definitive list of books included in IA's collections that were scanned by IA-employed workers at IA scanning centers.
#
# ## Experimental Design
#
# To do so, I, first, queried IA's advanced search database for texts where the uploader field contained the string "@archive.org" using the below html query: https://archive.org/advancedsearch.php?q=mediatype%3A%28texts%29&uploader%3A%28%40archive.org%29&fl%5B%5D=identifier&rows=14000000&output=csv&callback=callback&save=no
#
# Unlike the scanning center field, which is optional across all IA media, the uploader is a required metadata field for all items in IA's collection. It is not usually displayed on the resource page; rather, it is stored in the meta.xml metadata file for the item. The uploader field stores the email address affiliated with the account of the person responsible for uploading an item. IA's software automatically assigns it. See details about field below or by visiting IA's documentation: **uploader**
# - internal use only: Yes
# - usage notes: The uploader field determines which account has full access to modify/edit/delete metadata and files from the item without having any special privileges granted. Any other account that wants to modify this item must have some level of administrative privilege granted by Internet Archive.
# - definition: Email address of the account that uploaded the item to archive.org.
# - required: Yes
# - label: Item Uploader
# - repeatable: No
# - accepted values: Email address
# - edit access: IA admin
# - defined by: IA software
# - example: footage@panix.com
#
# ## Hypothesis
# Theoretically, all IA employees who are scanning materials at IA scanning centers should be issued an interet archive email address associated with their account. Therefore, this jupyter notebook will test the hypothesis that all items in the 14 million records with the string "@archive.org" in their uploader field will also be contained within the 9 million records scanned at IA scanning centers.

# %% [markdown]
# ## The 9 million records
# We are fairly confident the 9 million records in this csv file were scanned at IA based scanning centers.
#
# These records were discovered, first, by accessing 2 million records from Open Library's data dumps and discovering/geocoding 64 unique scanning centers. Next, we queried IA's database for records associated with each scanning center name. However, we had no reason to believe that open library's data dumps contained a text scanned at every scanning center. So, we broadened the search by querying major IA collections for the scanning center field of their contents. When a scanning center was no represented in the list gathered so far, we added it to the list of scanning centers. We performed this search for 14 IA collections:
# - americana
# - biodiversity
# - booksbylanguage_arabic
# - booksbylanguage
# - china
# - digitallibraryindia
# - europeanlibraries
# - folkscanomy
# - inlibrary
# - internetarchivebooks
# - JaiGyan
# - newspapers
# - printdisabled
# - toronto
#
# In total, we discovered 9 million records affiliated with 96 scanning centers (note these have not yet been deduplicated): 'shenzhen','hongkong','china','cebu','alberta','sfdowntown', 'tt_sanfrancisco','iala','indiana','euston','uoft','la','nj','santamonica','tt_pts','boston','beltsville','capitolhill','nyc','chapelhill','rich',
#  'richmond','richflorida','ill','il','edinburgh','sfciviccenter', 'maryland','raleigh','provo','washingtondc','tt_georgetown','sheridan','arch','miss','durham','durham2','providence','tt_providence','lond','london','manhattan','honolulu','rexburg','valencia','gainesville','tt_osu','tt_numismatic','tt_getty','tt_harvardernstmayr','pretoria','IIIT Hyderabad','CCL HYDERABAD','sacramento','beijing','tt_bangalore','tt_sok','trent','guatemala','tt_swinburne','BookScanUS','tt_amnh','harrisburg','amherst','tt_stanfordlaw','tt_pem','tt_calacademy', 'tt_jakarta','hangzhou','clemson','Osmania University','clarksville','tt_victoria','poughkeepsie','tt_warwick','tt_riks','1dollarscan (zLibro)','RMSC_IIITH','tt_stlouis','saltlakecity','tt_louisville','tt_oberlin','tt_clatsopcounty','brussels','tt_harrisburg','tt_statenisland','utah','hbl_storrs','tt_perkins','tt_harvardwidener','Hong Kong','AP Press Academy Archives','hamilton','tt_nybg','mobot','bali'

# %%
import pandas as pd

# %%
by_centers = pd.read_csv("/Volumes/Samsung_T5/scanning_labor_in_IA/texts-data.csv")
# Out:
# /var/folders/pl/rjmtml311bq31fb0njd03xlh0000gn/T/ipykernel_33627/1797296145.py:1: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   centers = pd.read_csv("/Volumes/Samsung_T5/scanning_labor_in_IA/texts-data.csv")

# %%
id_centers = by_centers['identifier'].tolist()

# %%
id_centers
# Out:
# ['geometrysuccessi00thom',
#  'berdiemobilittde00hebe',
#  'beilsteinshandb28beil',
#  'theoryapplicatio00adva',
#  'specialeditionus00edbo_0',
#  'surinamediscover00coll',
#  'tclcvolume99twen00thom',
#  'sweetdreams00pame',
#  'sitasnakequeenof00fran',
#  'sleepingwithherr00sher',
#  'talldarkstranger00smit',
#  'poemsaboutlove00grav',
#  'ponyinpumpkinpat00bagl',
#  'poohvisitsdoctor00kath',
#  'takingcareofbusi00leej',
#  'raisinggoodsport00sell',
#  'randomthoughts00crgi',
#  'shakespearecount00hill_0',
#  'aycubasocioeroti00codr',
#  'scienceannual199400lori',
#  'parisversailles00gray',
#  'nomercyhostofam00wals',
#  'mythologyofcrime00vict',
#  'namesofchrist00hort',
#  'nativeroadscompl00kosi',
#  'naturalmedicines00jell',
#  'oneshenandoahwin00bunn',
#  'opal00boul',
#  'operation00ande',
#  'publicaffairspri00bald',
#  'pumpkintownornot00mcky',
#  'puttingonglitzun00hatc',
#  'photoshop55image00wein',
#  'plantsofoceanthe00sueb',
#  'pharmacologyther00grol',
#  'peachpitpopulari00simp',
#  'promiseoffaith00wild',
#  'proudpeopleshe00alfo',
#  'psychologyscienc00croo_0',
#  'praisesinger1978rena',
#  'propheticlight00boyd',
#  'roughguidetoyuca00onei',
#  'rebelspretenders00chee',
#  'robotsandroidsme00dick',
#  'renewingfamilysp00ludw',
#  'residentialwirin00mark',
#  'religionnewmajo00stre',
#  'report000unit',
#  'rudygiuliani00bank',
#  'pagemaker5formac00benn',
#  'nourish00holl_0',
#  'novelstalesplays12gals',
#  'patrickhenryvoic00sabi',
#  'paintedcanoe00wink',
#  'paintingmoonfolk00with',
#  'palaceofkings00jeff',
#  'oraclecompletere00koch',
#  'pegasussecret00loom',
#  'plutoephemeris1900palm',
#  'pocketbabiesothe00coll',
#  'plantationboy00mura',
#  'numberofdragons00leed',
#  'nlfnationalliber00dona_0',
#  'naitokonanzenshu06nait',
#  'nanniesforhire00hest',
#  'nation207julnewy',
#  'naturestellingan00king',
#  'measurementforgu00roth',
#  'lovemelovemenoth00dole',
#  'lovenoirenovel00turn',
#  'worldtoonear00keny',
#  'mediaaccessorgan00fros',
#  'meditationsforne00bren',
#  'meijisentetsuiwa00anza',
#  'meimeilovesmorni00tsub',
#  'meinbettdastelef00',
#  'masscommunicatio00lent',
#  'merchantsmakehis00samh',
#  'merciroman00lind',
#  'merrychristmasba00mars',
#  'merrychristmassa00coco',
#  'metricsystemsimp00kell',
#  'miamidolphins00mcle',
#  'menopauseageofch00macf',
#  'mcgrawhilldictio02myer',
#  'mcgrawhillsinter00este',
#  'povertyinaffluen00will',
#  'primerfornewdisc00pugh',
#  'whateverysuccess00terr',
#  'paulmcfedrieswi000mcfe',
#  'websitesthatwork00blac',
#  'welfarestateintr00john',
#  'withoutcultureth00zakh',
#  'microsoftproject00douc_0',
#  'prayingwithteres00brou',
#  'womenautoimmuned00lahi',
#  'womenshomeremedi00publ',
#  'womentowomennewp00less',
#  'workinginagricul00shin',
#  'workingtogethera00trap',
#  'worldasweknowit00monn',
#  'worldseriesillus00leve',
#  'wrappedinpaperin00yunf',
#  'unauthorizedguid00schu',
#  'unburdenedheartf00nels',
#  'underrunners00mahy',
#  'understandinghum00tate',
#  'unfinishedwarvie00capp',
#  'yton00ceci',
#  'wherearemybirthp00grav',
#  'winningproductiv00slad',
#  'winteroffrozendr00hart',
#  'witchofhebronw00kuns',
#  'resumesfornursin00unse',
#  'questionofmax00cros_1',
#  'silencedwrathofg00jenk',
#  'theatermenschens00berg',
#  'landofwilliamofo00barn',
#  'vaticanimpressio00swee',
#  'veryyoungverses00geis',
#  'thingsaroundhous00zimh',
#  'thislittlepig00mile',
#  'tidewatertales00lock',
#  'timesavingrecipe00losa',
#  'vermonttroutstre00alle',
#  'truebookofautomo00carl',
#  'trygveliecoldw00barr',
#  'tinydotwhit00whit',
#  'toffsleepyc00crea',
#  'twelveapostles00fras',
#  'urbaneconomiesan00vick',
#  'thunderonleftins00aldr',
#  'spywholovedameri00lafl',
#  'dontlaughatmecre00yarr',
#  'startime00amie',
#  'sizeofworldoncea00gree',
#  'skateboarding00giff',
#  'sleepers00curr',
#  'sovietforeigneco00leon',
#  'spaceshuttle00bake',
#  'studentsguidetof00jenn',
#  'sugarisland00lama',
#  'strategiesforsur00lino',
#  'structureoffree000bayc',
#  'structuresofchur00kung',
#  'suddentimes00heal',
#  'stephencrane00cady',
#  'stmartinembroide00free',
#  'storyoforegon00lewi',
#  'storyofsilentnig00moor',
#  'storypowercompel00feeh',
#  'south00gamm',
#  'southbaybiketrai00bois',
#  'southofborder00cook',
#  'speaknoevil00kric',
#  'starship00rand',
#  'innightcafe000john',
#  'careersincomedy00menz',
#  'wanderingwarrior00chen',
#  'isbn_B000OTHUOQ',
#  'insearchofmobydi00seve_0',
#  'seventhmoon00gabr',
#  'whatjesusissayin00wall',
#  'whenileadwhydont00plac',
#  'yellowstonewilde00bart',
#  'youdoittoo00engl',
#  'youngamerica00amyp',
#  'younggeorgewashi00rose',
#  'wordsthatmustsom00boyl',
#  'treasuryoflovequ00hipp',
#  'whoamithistimeun00mart',
#  'wugatekeepersson00latt',
#  'whenallhellbreak00spen',
#  'whenbabycomeshom00bren',
#  'whendadsatsea00pelt',
#  'computersinhome00lytt',
#  'illustratedcompu00spen',
#  'elementarystatis00neis',
#  '76gnarlytrombone00pete',
#  '104stranitsyprol008800',
#  '150thingstomaked00moxl',
#  'imperfectjoy00stub',
#  '40s50sdesignsm00gilb',
#  '2000cfaleveliica00inst',
#  '200houseplantsan00gilb',
#  'dancingwithpower00fran',
#  'sunset131sepsout',
#  'sunset201sepsout',
#  'sunset168jansout',
#  'sunset213sepsout',
#  'fodors90portugal00lown',
#  'voicesinskystory00dwig',
#  'wampumsixpence00haye',
#  'warrenghardingam00kent',
#  'weareworldeva00scot',
#  'weathereverywher00case',
#  'waterhazard00dahl',
#  'hongkong00stei',
#  'sunset114jansout',
#  'sunset132aprsout',
#  'isbn_9780965373104',
#  'supremecourt00coyh',
#  'surgeryprinciplee3moye',
#  'testingchildren00ldre',
#  'textbookofanatom1948kimb',
#  'takingitlikewoma00oakl',
#  'completelifeency00mini',
#  'teachingreadinga00hall',
#  'summeriscotedazu00gifk',
#  'summerwinds00schi',
#  'survivalsuccessi00cron_0',
#  'suspectwrig00wrig',
#  'smallquilts00vane',
#  'smartwomansguide00king_0',
#  'slickrock00crum',
#  'simpleprintmakin00kent',
#  'madepossiblebysu00mart',
#  'toxicsludgeisgoo00stau_0',
#  'turnerimaginatio00gowi',
#  'bookofbuffalopot00altm',
#  'championsluck00thac',
#  'weishu8ce114juan03weis',
#  'microeconomicsan00bach',
#  'microsoftwindows00koer',
#  'microwavecooking00rutl',
#  'messagefrommatch00lisl_0',
#  'messagesfromowl00term',
#  'toloveeachotherw00scot',
#  'urbanamericacris00char',
#  'toomanyblackbird00ledb',
#  'soundblasterawe600crea',
#  'littlegirlherbee00wign',
#  'littlewolfpackle00whyb',
#  'liturgyeducation00shep',
#  'littleamerica00robs',
#  'littleblackcalfi00foyl',
#  '50americanheroes00dene',
#  '101backtoschoolj00eise',
#  '17lawsofsuccessf00rodm',
#  'americanvoter00joan',
#  'preventionsshort00chri',
#  'henrymooresculpt01moor',
#  'herecomesguide00bren',
#  'heredityintroduc00winc',
#  'hawaiitravelsurv00bend',
#  'historicportsmou00garv',
#  'hissleepingbeaut00grac',
#  'harriers00dick',
#  'harvestofreflect00mato',
#  'headofclassoralh00gabr',
#  'healthinelementa00walk',
#  'healthwisehandbo1990kemp',
#  'hearingp00prin',
#  'homebusinessbibl00eyle',
#  'howdidibecomemyp00harr_0',
#  'howelizabethbarr00medw',
#  'hpoffice560000hewl',
#  'icanbewelder00lill',
#  'icanreadaboutwha00ande',
#  'howprintinghelps00mcca',
#  'grandaddysstars00grif',
#  'isbn_9781463627317',
#  'isbn_9781560440277',
#  'isbn_9788280870117',
#  'isbn_9788403593565',
#  'isbn_9788501042514',
#  'isbn_9788886843010',
#  'isbn_9788970410821',
#  'isbn_9789021008486',
#  'isbn_9789572706442',
#  'isbn_9789573421139',
#  'isbn_9789574566198',
#  'isbn_9789576698620',
#  'isbn_9789620414350',
#  'isbn_9789622699144',
#  'isureamgladtosee00alex',
#  'islandofhopestor00sand',
#  'ispy00ford_0',
#  'historyofpennsyl00penn_0',
#  'hmospatientsbill00shap',
#  'isbn_9780942637076',
#  'isbn_9780964316140',
#  'isbn_9780965630443',
#  'isbn_9780971832831',
#  'isbn_9780972447232',
#  'isbn_9780980011869',
#  'isbn_9780981801209',
#  'isbn_9781427794918',
#  'isbn_9781439178317',
#  'isbn_9781439195147',
#  'isbn_9781567316087',
#  'isbn_9781568846651',
#  'isbn_9781570718236',
#  'isbn_9781570230769',
#  'isbn_9781573245364',
#  'isbn_9781575721330',
#  'isbn_9781577654117',
#  'isbn_9781579771232',
#  'isbn_9781581177008',
#  'isbn_9781582461342',
#  'isbn_9781588166456',
#  'isbn_9781590559673',
#  'isbn_9781592281701',
#  'isbn_9781596433885',
#  'isbn_9781598806564',
#  'isbn_9781605044446',
#  'isbn_9781740897570',
#  'isbn_9781880029428',
#  'isbn_9781931659024',
#  'isbn_9781932400113',
#  'isbn_9781933959023',
#  'isbn_9782246492214',
#  'isbn_9783548330921',
#  'isbn_9784041630198',
#  'isbn_9784088755038',
#  'isbn_9784062645492',
#  'isbn_9784140804339',
#  'isbn_9784167605087',
#  'isbn_9784152082367',
#  'isbn_9784198633103',
#  'isbn_9784560047187',
#  'isbn_9784569706351',
#  'isbn_9784844360940',
#  'isbn_9784871878906',
#  'isbn_9784883731213',
#  'isbn_9784939039072',
#  'isbn_9785170042777',
#  'isbn_9785170082964',
#  'isbn_9785170695553',
#  'isbn_9785224016044',
#  'isbn_9785237043945',
#  'isbn_9789729484995',
#  'isbn_9789861394398',
#  'isbn_9789861100906',
#  'isbn_9789861414058',
#  'isbn_9789861691305',
#  'isbn_9789861690377',
#  'isbn_9789861425801',
#  'isbn_9789864244966',
#  'isbn_9789864140008',
#  'isbn_9789889719555',
#  'isbn_B000H48SPI',
#  'isbn_B0087SD8ZG',
#  'isitchoiceanswer00marc',
#  'jpaulgettyoilbil00glas',
#  'kaplanpraxis201000kapl',
#  'kappacrossworddi00slka',
#  'kazakhstan00pang',
#  'keepoffire00anth',
#  'baronwar00sher',
#  'baseballbookreve00zand',
#  'basicessentialso00hodg',
#  'basiclumberengin00schw',
#  'balfourconspirac00stja',
#  'bakumatsuorandar00okub',
#  'bananaville00lill',
#  'augsburgsermonsf00augs',
#  'auntpleasantine00macd',
#  'bassinamericahau00baue',
#  'beachamsguidetoe01grap',
#  'beachdays00robb',
#  'beagleroth00roth',
#  'attackatnight00jack',
#  'attackofkillergr00wils',
#  'betterhealthcare00shul',
#  'betterhomesgarde1983wood',
#  'bettertimes00keef',
#  'americanrecordim02grae',
#  'andjusticeforsom00murp',
#  'andorracame00came',
#  'antarcticasforgo00quar',
#  'antiagingplanstr00royl',
#  'antarcticalastun00prin',
#  'bodycheck00chri',
#  'bodyworkpainting00newy',
#  'casesmaterialson00coxa',
#  'castlesofengland00john_0',
#  'casualbrutality00biss',
#  'catonhyacinthhun00doug',
#  'cattletrailsgita00pelt',
#  'cautionthismaybe00gayk',
#  'cavesbran00bran',
#  'cbgreenfieldpia00kall',
#  'cebubach00bach',
#  'celebratereading00scot',
#  'celebrationofsis00brow',
#  'ideaofuniversit00murp',
#  'ifihadyou00lynn',
#  'ifriverwaswhiske00boyl',
#  'ignitingreaches00drak',
#  'ijustneedmoretim00mill',
#  'greatwedding00evan',
#  'greekstonesspeak00mack',
#  'growingupwithsci09newy',
#  'growthinamerica00coop',
#  'growthofcities00hanm',
#  'growthtrainingvs00ortb',
#  'guidetoallchina00rand',
#  'guidetobeijinghe00bona',
#  'guidetocardiolog00klon',
#  'guidetocivilianj00voel',
#  'guidetonantucket00burr',
#  'hibearsbyebears00yekt',
#  'highlanders7200macd',
#  'highsteaks00loug',
#  'hightechnologyhu00laph',
#  'hirelingstale00bann',
#  'internationalmar00alba',
#  'internationalmig00taft',
#  'internationalorg00jord_0',
#  'internetworldgui00alle',
#  'invasionromaninv00pedd',
#  'investingforprof00armo',
#  'isbn_0717290905',
#  'isbn_0717294412',
#  'isbn_0738202053',
#  'isbn_0732712467',
#  'isbn_0809424029',
#  'isbn_0876544944',
#  'isbn_0880620706',
#  'isbn_0890612471',
#  'isbn_0910065748',
#  'isbn_0976215705',
#  'isbn_2840981211',
#  'isbn_8440610904',
#  'isbn_9684198817',
#  'isbn_9780007350803',
#  'isbn_9780130118530',
#  'isbn_9780130409331',
#  'isbn_9780201317770',
#  'isbn_9780201635874',
#  'isbn_9780312202019',
#  'isbn_9780312604530',
#  'isbn_9780373695171',
#  'isbn_9780373831173',
#  'isbn_9780439665513',
#  'isbn_9780440401537',
#  'isbn_9780440504856',
#  'isbn_9780446600590',
#  'isbn_9780465070633_0',
#  'isbn_9780553494310',
#  'isbn_9780670841844',
#  'isbn_9780671001667',
#  'isbn_9780671027407',
#  'isbn_9780671679187',
#  'infinitespace00gren',
#  'infinitevistasne00corn',
#  'informationretri00metc',
#  'ingeniousedgarjo00garn',
#  'inhalants00sher',
#  'inharmsway00bree',
#  'inhumanesocietya00foxm',
#  'inlittlekingdom00stie',
#  'inminute00mill',
#  'inmyfathershouse00wils',
#  'innameoflaw00lach',
#  'innightcafe00john',
#  'inpraiseofmusica00lewi',
#  'insideguidetoame00buar',
#  'insiderfrey00frey',
#  'insider00reec',
#  'insightoflord00bayn',
#  'isbn_0440136032',
#  'isbn_0440114764',
#  'isbn_0531151263',
#  'isbn_9780681103825',
#  'isbn_9780692002698',
#  'isbn_9780739489574',
#  'isbn_9780739493540',
#  'isbn_9780756624767',
#  'isbn_9780760737538',
#  'isbn_9780762725144',
#  'isbn_9780783623979',
#  'isbn_9780786702084',
#  'isbn_9780789425201',
#  'isbn_9780803725171',
#  'isbn_9780805978414',
#  'isbn_9780808027096',
#  'isbn_9780810124967',
#  'isbn_9780812579109',
#  'isbn_9780874479041',
#  'internationalcoo00bonn',
#  'introductiontomee4boyd',
#  'introductiontopr00smit',
#  'invisiblewedding00robb',
#  'instantwindforec00watt',
#  'instructorsresou00joan',
#  'integratedcircui00greb',
#  'integratingeduca00',
#  'integratingreadi00noyc',
#  'goldeneraoflittl00cost',
#  'heloiseshintsfor00helo',
#  'helooksthisway00curt',
#  'helpingyourselfw00will',
#  'hermothersdaught1987fren',
#  'herswornprotecto00ferr',
#  'hurricanestyphoo00jacq',
#  'hylapeepcrucifer00corn',
#  'iamcat00sche',
#  'iamnewone00isaa',
#  'iampositivebestm00davi',
#  'hommefatale00maye',
#  'hongkongindeptha00pome',
#  'horningingrownup00germ',
#  'horoscopo2012spa00kitt',
#  'hosieszoo00bask',
#  'hotair00bree',
#  'hudsonvalleypic00newy',
#  'humanbiology6the00sylv',
#  'humanbody07kerr',
#  'howtoarrangeflor00drie',
#  'howtobecaringchr00warr',
#  'howtocookwithher00town',
#  'howtohavefunwith00crea',
#  'hatsofftojohnste00chri',
#  'hauntedhouseothe00crum',
#  'guideforcollegeb00lina',
#  'guionblufordspac00jeff',
#  'guswandersoff00sche',
#  'handbookofchines00marg',
#  'handbookofcompos00wool',
#  'handybookofgarde00wilk',
#  'hangmanslane00wain',
#  'happybirthdaygar00namm',
#  'happydogs00mill',
#  'hardtrade00lyon',
#  'hardyraceofmenam00call',
#  'hardywing00wing',
#  'harimauv00voor',
#  'greatcontrovers00whit',
#  'greaterbostonpar00prim',
#  'greatgarlicbookg00aaro',
#  'greatgraverobber00mina',
#  'greatplacetowork00bloo',
#  'groomintraining00mart_0',
#  'italianodysseyea00fass',
#  'italy00blas_1',
#  'italy00ande',
#  'italy00salv',
#  'iwantsomebodytok00meek',
#  'iwanttobeenginee00grac',
#  'iwishihadreddres00clea',
#  'journeytochristm00chut',
#  'journeywithelsa000hadl',
#  'josephusdanielsi00cron',
#  'josieshandfulofq00smit',
#  'journalforjordan00cane',
#  'journalofcolonel00bell',
#  'itstimeforchrist00sech',
#  'jacobswoundsearc00herr',
#  'jameslouispetigr00peas',
#  'janine00mcko',
#  'jazzguidenewyork00doll',
#  'jealousy00scho',
#  'joebluejaycarlca00dugo',
#  'jellydonutdietbo00grey',
#  'jesusblesseschil00trui',
#  'jesuschristkingd00gall',
#  'jesusfishermen00maie',
#  'jerrybakersflowe00bake',
#  'jimthorpelegenda00long',
#  'jinshu130juan05fang',
#  'jinx00kahn',
#  'innplacesmosthig00slfe',
#  'insearchofmanrea00gree',
#  'insectsofrainfor00wood',
#  'insideboardroomg00bowe_0',
#  'indianacodecompr09indi',
#  'indianastateloca00sike',
#  'incompatibilityo00fast',
#  'kilaueanewestlan00dori',
#  'bestteacherstest00rese',
#  'christmascarolscholastic00dick',
#  'demonsoul00knaa',
#  'rhodeislandspiri00boda',
#  'chaloucarl00carl',
#  '98p0sgettinghott00spar',
#  'esquire140sepchic',
#  'isbn_9780373694983',
#  '1985comptonsyear00feco',
#  'englishpaperstea00prit',
#  'fewgoodmen00over',
#  'hockeymachine00chri_0',
#  '250tipsformaking00schw',
#  'howtocareforyour00scho',
#  'howtodoeverythin00plot',
#  'hidebutterflytea00echo',
#  'hotwordsforsati00lind',
#  'humanitiescultur02witt',
#  'herecomessantacl00hove',
#  'heroforleanda00andr',
#  'hachettegdegrtbr00hach',
#  'environmentalpea00kenc',
#  'beststoriesofame00marc',
#  'businessiscontac00rich',
#  'blownaway00kirk',
#  'billofrightstrue00patr',
#  'climbingjacobsla00lang',
#  'claroquesi00luci',
#  'hungrytigerstory00came',
#  'healthspanclaimy00wood',
#  'harrapsmicrospan00harr',
#  'hannaboyscenterh00byrn',
#  'hannahshelpingha00vanl',
#  'brigofwarnathani00rich',
#  'greyarms00arms',
#  'grieving00ruth',
#  'authenticitycont00gilm',
#  'fourteendilemma00pent',
#  'francie00engl',
#  'foreverandbaby00earl',
#  'advancedjavaidio00laff',
#  'frommersnewyorks00fore',
#  'freshfaithwhatha00cymb',
#  'babytrailnovel00mori',
#  'balancedscience200geof',
#  'baedekersparis00kott',
#  'fiendinhuman00gray',
#  'fifthhorseman00vill',
#  'bendinroad00nich',
#  'baseballamericas00edib',
#  'gardenersguideto00davi',
#  'bridegroomthanky00nayl',
#  'greatweddingpart00donn',
#  'greatestmusictri00sull',
#  'gracepoint00anne',
#  'guidetoamericanl08west',
#  'fragranceofkindn00full',
#  'fitnessexercises00amyl',
#  'fitnesswalking00ikno_0',
#  'gmat00lear',
#  'hollywoodpanoram00harm',
#  'holocaustotherpo00sonn',
#  'hanshottermemoir00hott',
#  'ridecockhorse00kenn',
#  'officialguidetop00educ',
#  'isbn_9785224025718',
#  'familyofreadersb00roge',
#  'fodors2008northe00fodo',
#  'followmehomeshor00hoff',
#  'fodorscruisespor00schw',
#  'frequentlyaskedq00bais',
#  'freebirth00thur',
#  'familybeachhouse00cham',
#  'fathergodcocreat00brow',
#  'anothermansson00ston_0',
#  'notesonpathologi00mcne',
#  'eggcheesemenus00time',
#  'executiveinactio00druc',
#  'exercisinginflue00barn',
#  'facesunderwater00leet',
#  'footfallsinmemor00wait',
#  'fortunesbridebab00donn',
#  'france00stur',
#  'familycreativevol2newy',
#  'federalinvestiga00otte',
#  'fatherfiguresthr00swee',
#  'fearitself00schu',
#  'feastoflight00norr',
#  'fundamentalvolle00jens',
#  'frontofhouse00oliv',
#  'knights00daly_0',
#  'japan00daws',
#  'japanasianpower00irwi',
#  'jesusisoursavior00noic',
#  'jimcramersstayma00cram',
#  'ladykiller00odon',
#  'lapapilleoptique00bona',
#  'laroussesfrenche00wash',
#  'laststandofmrame00flor',
#  'juliotyma00tyma',
#  'justgivemelittle00lori',
#  'libraryjournal107sep',
#  'libraryjournal121may',
#  'lifewithoutdisea00schw',
#  'lightforlifestun00rice',
#  'isbn_9781450718882',
#  'isbn_9781573924887',
#  'isbn_9781601621887',
#  'isbn_9781608192809',
#  'livingwithasthma00rook',
#  'littlerednewt00harr',
#  'iamfromafricatra00emma',
#  'imperialladyfant00nort',
#  'idontfeelcalledt00hill',
#  'goldengatebridge00nels',
#  'goldentusk00slau',
#  'growingmorelikej00stra',
#  'harpersmagazine198alde',
#  'heavensroad00pell',
#  'guidanceapproach00gart',
#  'hallmarkbookofsh00hear',
#  'goodneighborsnov00bech',
#  'maybeyoubelongin00ocon',
#  'manwithglovedhan00mcki',
#  'magicianmctree00coom',
#  'maincitieseurope00mich',
#  'makingamericanfo00brig',
#  'makinglifemoreli00dick',
#  'mantheyhanged00stee',
#  'lucky1300barn',
#  'maltesedigi00digi',
#  'indebtedsocietya00medo',
#  'focusonmarijuana00zell',
#  'foldedstarmitred00wrig',
#  'foolserrandnovel00norm',
#  'freemoneyforgrad00blum',
#  'rogetsthesaurusoma00maws',
#  'firstyearteache000will',
#  'fish00henr',
#  'flightofwitch00elli',
#  'flipswitchlosewe00coop',
#  'financialessenti00tabe_0',
#  'findingian00came',
#  'existentialismmo00hein',
#  'estateofgrace00powe',
#  'corporationsareg00dana',
#  'lccn_09334070040',
#  'lionsshare00camp',
#  'littlefoxstoryof00keel',
#  'nakedhearttalkin00ever',
#  'meetjerryspinell00mcgi',
#  'mergersacquisiti00arth',
#  'michaelberenstai00bere',
#  'modernbelgium00boud',
#  'murdermostmellow00gird_0',
#  'monkeywildwildwi00john',
#  'niagaraattractin00nyhu',
#  'nighttennis00davi',
#  'nightsunpoems00shur',
#  'nighttheyburnedm00dool',
#  'newplaysforredle00sech',
#  'nclexrn00barb',
#  'onicemacg00macg',
#  'ordinarygraceexa00breh',
#  'natsunohikari008800',
#  'naughtynomoreurb00bren',
#  'nelson00wilk',
#  'olivercatonplane00kett',
#  'onceupontartsoup00ment',
#  'onecircus3ringsf00pint',
#  'onroadtotetlama00conr',
#  'peircescoloniall00peir',
#  'murderingeorgeto1986trum',
#  'mysterytriviaqui00rees',
#  'dannasbestfriend00slat',
#  'mothertheodoregu00mitc',
#  'mountainman00thie',
#  'mountrainiernati00nels',
#  'nutsboltsgutleve00shav',
#  'folktalesfromsov00babl',
#  'whatmodernhypnot00petr',
#  'longestnightmili00eich',
#  'feverlifemusicof00rich',
#  'sociology00scha_5',
#  'atlasofworldhist00rand',
#  'ripleysbelieveit00ripl_5',
#  'storybookmazes00dave',
#  'nathanielhawthor00wage',
#  'bookbybooknoteso00dird',
#  'neitherheroineno00cory',
#  'storyofmymisfort00abel',
#  'hiddenbaja00rich',
#  'daybydayseventie00leon',
#  'snowflakecutuses00sibb',
#  'isbn_0382084098',
#  'lovinggodstudygu00char',
#  'hugohugochavezst00jone',
#  'streetcarsatpass00rona',
#  'businesslaw00paus',
#  'awakening00deve',
#  'southernodysseys00ande',
#  'coreskillstestpr00stec',
#  'lightshadow00greg',
#  'scrapbookingfrie00crea',
#  'dancesingremembe00kimm',
#  'honkytonkheroesh00geor',
#  'guildofxenolingu00finc',
#  'orientalarchitec00buss',
#  'christmasjoykeep00bran',
#  'moxieamericancha00weld',
#  'answerman00royj',
#  'goldinwater00phmu',
#  'conjurerprincess00vivi',
#  'ballotforamerica00buch',
#  'colorofourfuture00chid',
#  'lionmouse00jone',
#  'hiddenmagic00vand',
#  'alfredkroppsealo00yanc',
#  'ondarkofmoon00lang',
#  'visions00nowr',
#  'handcraftedchris00dawn',
#  'franklinhassleep00bour',
#  'troublegum00cord',
#  'statebuildinginc00lees',
#  'beginningletters00',
#  'developinglea00maxw',
#  'hollyinlove00caro',
#  'mangiasoupssalad00rica',
#  'madeinwestafrica00pric',
#  'chynablack00keis',
#  'mybestfriendmove00carl',
#  'americanjurispru02lawy',
#  'grandslamcassand00mood',
#  'montessoriplayle00brit',
#  'storiesofbuddhab00caro',
#  'genetics00else',
#  'principlesofbank00carr',
#  'helloisthisgrand00ianw',
#  'nowweregoingtoha00olip',
#  'bloodmoneywasted00mill',
#  'mrsgbs00d8',
#  'americanhomefron00cook',
#  'towardpeacesecur00glic',
#  'onedayatfenwayda00kett',
#  'kingofwind00marg',
#  'poppletonhasfun00ryla',
#  'questforcontinen00sull',
#  'puppyparade00venn',
#  'kabbalahmethod00ravp',
#  'lieutenantsladyt00raem',
#  'gettingbyinhebre00pell',
#  'coldfire000koon',
#  'capitalistpatria00alis',
#  'taleoftwocities00char_0',
#  'miningebaywebser00john',
#  'islandofdrmoreau00well_0',
#  'dutchwithouttoil00cher',
#  'dynamicalphysica00halt',
#  'isbn_0898434718',
#  'emiliebarnes15mi00emil',
#  'catholicchurchs00kung',
#  'sidelightsonquee00pons',
#  'amberbrownisnotc00danz_1',
#  'demisdragonsfant00demi',
#  'thismatterofmarr00maco',
#  'liehtzutaoistgui00liez',
#  'discoveryoursens00kees',
#  'isbn_9781580173360',
#  'mrmertonsvacatio00dian',
#  'isbn_9785237050097',
#  'probabilitystati00sche',
#  'silent00dann',
#  'witherbysdiction00cock',
#  'widewindow00snic',
#  'chronocrusadevol00dais',
#  'linkletterdownun00link',
#  'onceinneverout00maho',
#  'iammyownbestcasu00gold_0',
#  'heritageofmusic00ship',
#  'foxthatwantednin00knig',
#  'portraitofladygo00henr',
#  'christmaswithvic00jenn',
#  'animalsofwoodlan00debo',
#  'gaydecorationswi00denn',
#  'dennisonpartiesw00denn',
#  'leavegravegreend00debo',
#  'isbn_9780813314778',
#  'saratogahot00cali',
#  'desertworld00jouv_0',
#  'fullcircle00bunn',
#  'confidenceafrica00mart',
#  'devilsprotection00clit',
#  'drowningman00coel',
#  'californiaeditor00stor',
#  'listentowild00hart_1',
#  'runningmicrosoft00russ',
#  'threemusketeersg00alex',
#  'caringforyourpar00macl',
#  'risottorisotti00barr',
#  'cuttingmustardaf00hein',
#  'waltdisneyaristo00walt',
#  'reluctantneighbo00henr',
#  'coldwareurope19400john',
#  'foodforthought00stev',
#  'betterhomesgarde59jandesm',
#  'newpracticalhome00cass',
#  'happyendingsarea00scop',
#  'marvelboymarvelk00jgjo',
#  'africanart00reaw',
#  'betterhomesgarde58jandesm',
#  'strudwicksheepin00krau',
#  'healthypleasures00orns',
#  'singerssweethear00dewj',
#  'georgewashington00kenn',
#  'quiltsquiltsmore00mccl',
#  'claudemonetfirst00petr',
#  'royaltonraid00dean',
#  'generalchemistry00roch',
#  'christmascooking00purd',
#  'olympicsummergam00arno',
#  'headfirstjava00sier_0',
#  'popularsciencedo12howt',
#  'isbn_9782849901335',
#  'billcosby00sanf',
#  'biggestlittlebri00jimb',
#  'propheticminorit00newf',
#  'secret00vict',
#  'javafordummies00wals_0',
#  'otherwoman00dick',
#  'unclewiggilyhisf00howa',
#  'stockcars00will',
#  'yourcompleteguid00vall',
#  'appliedmicroecon00mans',
#  'followmyleader00jame',
#  'onpopulationthre00malt',
#  'currentbiogr198600mori',
#  'sportsencycloped00davi',
#  'starlightwarrior00erin',
#  'bobsfavoritefixi00newy',
#  'summoned00doke',
#  'laurelsevenbride00leig',
#  'itsmehippo00thal',
#  'decoratingideasn00desm',
#  'alchemastersappr00walt',
#  'romanylife00petu',
#  'tommasoblindphot00bufa',
#  'carriers000lync',
#  'twodimensionalfi00bewl',
#  'wildgratitudepoe00hirs',
#  'babyletseatwelco00rena',
#  'strangeworld00edwa',
#  'introductiontohu00solo_0',
#  'calculus00finn',
#  'classicalmusicro00buck',
#  'latemiddleages00bart',
#  'upyourbannersnov00west',
#  'personalpowerfor00tayl',
#  'othersideofmulho00rand',
#  'codebreaking00rudo',
#  'billyjoelbiograp00bego',
#  'nietzschemodernl00mayk',
#  'oldpriory00loft',
#  'momentoffreedomh00bj',
#  'sixexistentialhe00luci',
#  '2corinthiansgala21geor',
#  'mothersknowevery00pete',
#  'knightspassion00kohl',
#  'lieutenantkijy008800',
#  'linkednewscience00bara',
#  'overlandescapean00leer',
#  'muggsyboguestall00reis',
#  'policeskillscien00colb',
#  'isbn_9780373129522',
#  'expressionismger00vogt',
#  'macroeconomics00mank_0',
#  'strikeforceorgan00moll',
#  'isbn_9789683805829_0',
#  'versionsofpast00harr',
#  'isbn_9781439218457',
#  'withcontrasrepo00dick',
#  'hugojosephine00grip',
#  'heyworldhereiam00jean',
#  'withoutestrogen00amyg',
#  'crumbsdontcountr00bind',
#  'contemporarynort00yora',
#  'irishharpbook00shei',
#  'shadowoffear00pear',
#  'historyofphysics00asim',
#  'deathintrenchesg00davi',
#  'toiletsbathtubss00colm',
#  'collectorscompas00coll',
#  'mafia00dori',
#  'fighterwingguide00tomc',
#  'giftsfromeykis00wayn',
#  'firstloveothersh00samu',
#  'trainride00step',
#  'yonekodaughterof00taha',
#  'cohousingcontemp00mcca',
#  'isbn_014005782x',
#  'symbolisminrelig00mayr_0',
#  'rancherswifewest00anne',
#  'isbn_9780618483990',
#  'pregnanttycoon00ande',
#  'sukarnoautobiogr00soek',
#  'amiablegiant00slob',
#  'journalsofsylvia00plat_0',
#  'bonengfa00ngfa',
#  'storyofbostont00stei',
#  'theycametoseepoe00roze',
#  'escapadesoffrank00brei',
#  'isbn_9780764531965',
#  'isbn_9780764533174',
#  'isbn_9780787635275',
#  'isbn_9780787686574',
#  'isbn_9780816028481',
#  'isbn_9780883657478',
#  'isbn_9780937188705',
#  'treatmentofnarci00spot',
#  'ringsoftauteesta00dean',
#  'crisantemoschrys00nune',
#  'isbn_9781869501945',
#  'isbn_9784062065665',
#  'stubbornforliber00kenn',
#  'shambhalasacredp00trun_0',
#  'ultimatefrenchbe00hemi',
#  'foundationsofwes04nobl',
#  'faithreasoninkie00frus',
#  'disneys101dalma00korm',
#  'illustratedscien06newy',
#  ...]

# %%
# the request timed out at 1 million, so i need to repeat :()
by_uploaders = pd.read_csv('/Volumes/Samsung_T5/scanning_labor_in_IA/ia_scanned_ids.csv')

# %%
by_uploaders
# Out:
#                             identifier
# 0                       DFD29_20171225
# 1              the-trace-of-interbeing
# 2         fold1.harrisburg.archive.org
# 3                   SalmosAlabadFELiRe
# 4                      satrss_20170810
# ...                                ...
# 11694995                jstor-30065112
# 11694996                       eoab042
# 11694997  State-Dept-cable-1975-179735
# 11694998                jstor-30065212
# 11694999  State-Dept-cable-1975-179764
#
# [11695000 rows x 1 columns]
