# %%
import pandas as pd
import os
import ast
import json
import altair as alt

# %%
hongkong_file = "/Users/elizabethschwartz/Documents/spring_2023/culture_at_scale/ia_infrastructure_proj/scandates/hong-center-with-context.json"

# %%
with open(hongkong_file, 'r') as f:
  hongkong = json.load(f)

# %%
hongkong = hongkong['docs']

# %%
hongkong_df = pd.DataFrame(hongkong)

# %%
hongkong_df
# Out:
#                                         donor        scandate  \
# 0                                  blogistics  20180724133739
# 1                                         NaN  20180611023417
# 2                                         NaN  20181224163053
# 3                    internetarchivebookdrive  20180813120333
# 4                         bostonpubliclibrary  20180818203457
# ...                                       ...             ...
# 480731                                    NaN  20190111110720
# 480732            bostonpubliclibrarydonation  20170311111204
# 480733                                    NaN  20181204170115
# 480734  friendsofthesanfranciscopubliclibrary  20180825215354
# 480735                                    NaN  20181012013034
#
#        shipping_container
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 480731                NaN
# 480732             SZ0024
# 480733                NaN
# 480734                NaN
# 480735                NaN
#
# [480736 rows x 3 columns]

# %%
hongkong_df[[isinstance(val, list) for val in hongkong_df['donor'].values]]
# Out:
#                                                  donor        scandate  \
# 453     [Kensington Library, internetarchivebookdrive]  20170330154643
# 547     [Kensington Library, internetarchivebookdrive]  20160629024234
# 782     [Kensington Library, internetarchivebookdrive]  20160625140354
# 1770            [nclivedonation, unclibrariesdonation]  20180831045805
# 3827    [Kensington Library, internetarchivebookdrive]  20170907171010
# ...                                                ...             ...
# 475458  [Kensington Library, internetarchivebookdrive]  20171024232347
# 475913  [Kensington Library, internetarchivebookdrive]  20171012084314
# 477535  [Kensington Library, internetarchivebookdrive]  20160628150129
# 478620  [Kensington Library, internetarchivebookdrive]  20170405145151
# 480692  [Kensington Library, internetarchivebookdrive]  20170331092842
#
#        shipping_container
# 453                SZ0024
# 547                SZ0024
# 782                SZ0024
# 1770                  NaN
# 3827               SZ0024
# ...                   ...
# 475458             SZ0024
# 475913             SZ0024
# 477535             SZ0024
# 478620             SZ0024
# 480692             SZ0024
#
# [266 rows x 3 columns]

# %%
refac_hk = []
for item in hongkong: 
    print(item)
    try:
        if type(item['donor']) == list:
            item['donor'] = str(item['donor'])
    except KeyError:
        pass
    
    refac_hk.append(item)
# Out:
# {'donor': 'blogistics', 'scandate': '20180724133739'}
# {'scandate': '20180611023417'}
# {'scandate': '20181224163053'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180813120333'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180818203457'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161226094110', 'shipping_container': 'SZ0023'}
# {'scandate': '20180601002523'}
# {'scandate': '20181120163321'}
# {'donor': 'bwb', 'scandate': '20170625132952', 'shipping_container': 'SZ0025'}
# {'scandate': '20180928141045'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180103084951'}
# {'scandate': '20181021111759'}
# {'donor': 'alibris', 'scandate': '20171203194109'}
# {'scandate': '20180607070707'}
# {'donor': 'allen_county', 'scandate': '20180703152837', 'shipping_container': 'SZ0025'}
# {'scandate': '20180816135452'}
# {'scandate': '20180906162753'}
# {'scandate': '20190103135123'}
# {'scandate': '20181211224639'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180814115126'}
# {'donor': 'bostonpubliclibrarydonation', 'scandate': '20170319151247', 'shipping_container': 'SZ0024'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170811011930'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180123155308'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170303025149', 'shipping_container': 'SZ0023'}
# {'donor': 'alibris', 'scandate': '20171202180324'}
# {'scandate': '20181008143530'}
# {'scandate': '20181010222836'}
# {'scandate': '20181031113914'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170827183218'}
# {'scandate': '20180528070208'}
# {'scandate': '20180828060840'}
# {'scandate': '20181105035021'}
# {'scandate': '20180211104857'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171121095149'}
# {'donor': 'allen_county', 'scandate': '20171018195643', 'shipping_container': 'SZ0024'}
# {'scandate': '20180830152016'}
# {'scandate': '20181113082721'}
# {'scandate': '20180315040437'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160623130949', 'shipping_container': 'SZ0024'}
# {'donor': 'bwb', 'scandate': '20170611075604', 'shipping_container': 'SZ0025'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180829164312'}
# {'scandate': '20180525084556'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170215043959', 'shipping_container': 'SZ0024'}
# {'scandate': '20180921164943'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170816205549'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180208092327', 'shipping_container': 'SZ0025'}
# {'scandate': '20180627090535'}
# {'donor': 'alibris', 'scandate': '20170419050924'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171212044600'}
# {'scandate': '20180830103609'}
# {'scandate': '20180616212846'}
# {'scandate': '20180930140515'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170325222112', 'shipping_container': 'SZ0024'}
# {'scandate': '20181101214607'}
# {'scandate': '20181121182716'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170406155558', 'shipping_container': 'SZ0024'}
# {'scandate': '20180423110736'}
# {'donor': 'alibris', 'scandate': '20170414172921'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170301045701', 'shipping_container': 'SZ0023'}
# {'scandate': '20181119110025'}
# {'donor': 'blogistics', 'scandate': '20180828123454'}
# {'donor': 'alibris', 'scandate': '20180830063908'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180106091700'}
# {'scandate': '20181203022039'}
# {'scandate': '20180515042104'}
# {'scandate': '20180820105253'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180721034820'}
# {'scandate': '20180110021912'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160728192828', 'shipping_container': 'SZ0024'}
# {'scandate': '20181101101322'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180628231947', 'shipping_container': 'SZ0025'}
# {'scandate': '20180602123516'}
# {'scandate': '20180517122851'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171214001241'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170929051746', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161129124352', 'shipping_container': 'SZ0023'}
# {'donor': 'cityofsausalitolibrary', 'scandate': '20160714175017', 'shipping_container': 'SZ0024'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20170211095947', 'shipping_container': 'SZ0023'}
# {'scandate': '20180730013808'}
# {'scandate': '20180407140039'}
# {'donor': 'blogistics', 'scandate': '20170830141247'}
# {'donor': 'alibris', 'scandate': '20170501160225'}
# {'donor': 'alibris', 'scandate': '20180814160423'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161217023720', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161014042844', 'shipping_container': 'SZ0023'}
# {'scandate': '20190103111425'}
# {'donor': 'bwb', 'scandate': '20160712040313', 'shipping_container': 'SZ0024'}
# {'donor': 'blogistics', 'scandate': '20170808224700'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170412112851', 'shipping_container': 'SZ0024'}
# {'donor': 'allen_county', 'scandate': '20171025163853', 'shipping_container': 'SZ0025'}
# {'scandate': '20180714003707'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161215024417', 'shipping_container': 'SZ0023'}
# {'scandate': '20180905120803'}
# {'scandate': '20180913043324'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170409103945', 'shipping_container': 'SZ0024'}
# {'scandate': '20180302065351'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170508182629'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171111124509'}
# {'scandate': '20181014012436'}
# {'scandate': '20190105045000'}
# {'scandate': '20180829112232'}
# {'scandate': '20180801045724'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170811232944', 'shipping_container': 'SZ0025'}
# {'scandate': '20190108140806'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180910090921'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170928095221'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161227051259', 'shipping_container': 'SZ0023'}
# {'scandate': '20180930214131'}
# {'scandate': '20180719044225'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180201120537'}
# {'donor': 'alibris', 'scandate': '20171013121042', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrarydonation', 'scandate': '20170303044735', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170821214157'}
# {'donor': 'Boston Public', 'scandate': '20170606024953'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180121001912'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170107154611', 'shipping_container': 'SZ0023'}
# {'scandate': '20171215052537'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171122034615'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171122043946'}
# {'scandate': '20180407074752'}
# {'scandate': '20180706125319'}
# {'scandate': '20180801075206'}
# {'donor': 'alibris', 'scandate': '20180311081942'}
# {'scandate': '20181109063114'}
# {'scandate': '20190112182710'}
# {'scandate': '20181115173815'}
# {'donor': 'blogistics', 'scandate': '20170513195914'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170716073936'}
# {'scandate': '20180207072134'}
# {'scandate': '20180921042603'}
# {'donor': 'allen_county', 'scandate': '20170417072657'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171221160214'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171023092429', 'shipping_container': 'SZ0024'}
# {'scandate': '20180718173458'}
# {'scandate': '20180301071653'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170210132659', 'shipping_container': 'SZ0024'}
# {'scandate': '20181207133316'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170921090932'}
# {'donor': 'marincountyfreelibrary', 'scandate': '20180803034005'}
# {'scandate': '20171219112353'}
# {'donor': 'Peninsula Library System', 'scandate': '20170505221535'}
# {'scandate': '20180622114350'}
# {'scandate': '20180710034641'}
# {'scandate': '20170523015409'}
# {'scandate': '20181114034018'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20171118091657'}
# {'scandate': '20180728124929'}
# {'scandate': '20181022115133'}
# {'scandate': '20180927033314'}
# {'scandate': '20180221235226'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171202085329'}
# {'donor': 'alibris', 'scandate': '20180730215946'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170221161232', 'shipping_container': 'SZ0025'}
# {'scandate': '20180714114736'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180808201552'}
# {'scandate': '20180227134625'}
# {'donor': 'blogistics', 'scandate': '20171121032556'}
# {'scandate': '20181221090502'}
# {'scandate': '20180905113935'}
# {'donor': 'blogistics', 'scandate': '20180729082456'}
# {'scandate': '20180629055913'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171224023540'}
# {'scandate': '20180728011612'}
# {'donor': 'bwb', 'scandate': '20170726084123', 'shipping_container': 'SZ0025'}
# {'scandate': '20180211134607'}
# {'donor': 'alibris', 'scandate': '20180728184941'}
# {'scandate': '20180612171140'}
# {'scandate': '20181116190159'}
# {'donor': 'alibris', 'scandate': '20180821101205'}
# {'donor': 'blogistics', 'scandate': '20180816102127'}
# {'scandate': '20181026224721'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170909233454'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161207051350', 'shipping_container': 'SZ0023'}
# {'scandate': '20180822035734'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180903121438'}
# {'scandate': '20180626083241'}
# {'scandate': '20180928074734'}
# {'scandate': '20181225083557'}
# {'donor': 'allen_countydonation', 'scandate': '20170518171341'}
# {'donor': 'allen_county', 'scandate': '20170511142406'}
# {'scandate': '20180327170819'}
# {'scandate': '20180719210224'}
# {'scandate': '20180201011939'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171027102535', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170107094356', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170729224431'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170527091633'}
# {'scandate': '20180525013707'}
# {'scandate': '20181003161932'}
# {'scandate': '20180206053626'}
# {'scandate': '20181121142648'}
# {'donor': 'bwb', 'scandate': '20160808230357', 'shipping_container': 'SZ0024'}
# {'donor': 'blogistics', 'scandate': '20170722154158'}
# {'donor': 'cityofsausalitolibrary', 'scandate': '20160912152303', 'shipping_container': 'SZ0024'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171209103030'}
# {'scandate': '20171019032645'}
# {'scandate': '20171030112447'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20171011180148', 'shipping_container': 'SZ0025'}
# {'scandate': '20180521084824'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161227101655', 'shipping_container': 'SZ0023'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180725173421'}
# {'scandate': '20180201180818'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171123052704'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180724170325'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161219105242', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180720062236', 'shipping_container': 'SZ0025'}
# {'donor': 'allen_county', 'scandate': '20171026172322', 'shipping_container': 'SZ0025'}
# {'scandate': '20181031014502'}
# {'scandate': '20171227093419'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180803092455'}
# {'scandate': '20180601233833'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170525130334'}
# {'scandate': '20181020113052'}
# {'scandate': '20181009121100'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180204115251'}
# {'scandate': '20180501124001'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170822213650'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180827041201'}
# {'scandate': '20181210123640'}
# {'donor': 'bwb', 'scandate': '20160706061645', 'shipping_container': 'SZ0024'}
# {'scandate': '20180601164503'}
# {'scandate': '20180711072424'}
# {'scandate': '20180312093448'}
# {'scandate': '20180806232950'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171110173231'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20170811223852', 'shipping_container': 'SZ0025'}
# {'scandate': '20180601202129'}
# {'donor': 'allen_countydonation', 'scandate': '20170701042130', 'shipping_container': 'SZ0025'}
# {'scandate': '20180319214545'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170111055228', 'shipping_container': 'SZ0023'}
# {'donor': 'alibris', 'scandate': '20171107101741'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171205135723'}
# {'scandate': '20180404070534'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171116142032'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170323114609', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180704020635', 'shipping_container': 'SZ0025'}
# {'scandate': '20180606161519'}
# {'scandate': '20190108145340'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180706102244', 'shipping_container': 'SZ0025'}
# {'scandate': '20180530092728'}
# {'scandate': '20180223074805'}
# {'donor': 'alibris', 'scandate': '20180121221450'}
# {'scandate': '20181010125824'}
# {'scandate': '20180507062057'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170309071016', 'shipping_container': 'SZ0023'}
# {'scandate': '20181122110355'}
# {'scandate': '20180626115148'}
# {'donor': 'blogistics', 'scandate': '20180811212457'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171113111036'}
# {'donor': 'alibris', 'scandate': '20180123150407'}
# {'donor': 'alibris', 'scandate': '20170310032327', 'shipping_container': 'SZ0024'}
# {'donor': 'belvederetiburonlibrary', 'scandate': '20180903081712'}
# {'scandate': '20181012134356'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161124034933', 'shipping_container': 'SZ0023'}
# {'scandate': '20181003200534'}
# {'scandate': '20180804060113'}
# {'scandate': '20181123040537'}
# {'scandate': '20180711182152'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160624032642', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160622150848', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170713103237', 'shipping_container': 'SZ0025'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171110064234'}
# {'scandate': '20180315181903'}
# {'donor': 'allen_county', 'scandate': '20170711085153'}
# {'donor': 'alibris', 'scandate': '20171011100119', 'shipping_container': 'SZ0024'}
# {'scandate': '20180211060738'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170928020651', 'shipping_container': 'SZ0025'}
# {'donor': 'alibris', 'scandate': '20170414084150'}
# {'scandate': '20180221041301'}
# {'scandate': '20181207060045'}
# {'scandate': '20180211060352'}
# {'scandate': '20181027133148'}
# {'scandate': '20180201011953'}
# {'scandate': '20181129152440'}
# {'scandate': '20180321043057'}
# {'scandate': '20180929054115'}
# {'scandate': '20180616040942'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170902214717'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180530151115'}
# {'scandate': '20180310063813'}
# {'scandate': '20181030041659'}
# {'donor': 'bwb', 'scandate': '20170612084140', 'shipping_container': 'SZ0025'}
# {'donor': 'alibris', 'scandate': '20180830042240'}
# {'scandate': '20181219165648'}
# {'scandate': '20180103075942'}
# {'scandate': '20180508123946'}
# {'scandate': '20180830174926'}
# {'donor': 'alibris', 'scandate': '20180131010716'}
# {'scandate': '20180414073001'}
# {'scandate': '20181207145156'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180129064428'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160820071320', 'shipping_container': 'SZ0024'}
# {'donor': 'allen_county', 'scandate': '20180125123239', 'shipping_container': 'SZ0025'}
# {'scandate': '20180321004102'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20170917035215'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170706041748', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170801013112'}
# {'scandate': '20181216150356'}
# {'scandate': '20180517232655'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170727215050'}
# {'scandate': '20180717045632'}
# {'scandate': '20190117204551'}
# {'scandate': '20180623234759'}
# {'scandate': '20180907105428'}
# {'scandate': '20180718130002'}
# {'scandate': '20181030074816'}
# {'scandate': '20180203195409'}
# {'scandate': '20180310030450'}
# {'scandate': '20180719055005'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171125110122'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170803231020'}
# {'scandate': '20180904202833'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170927131404', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180819150321'}
# {'scandate': '20181125193623'}
# {'scandate': '20180517135540'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180830201157'}
# {'scandate': '20180919095548'}
# {'scandate': '20180920080117'}
# {'scandate': '20181129130755'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161101221631', 'shipping_container': 'SZ0023'}
# {'scandate': '20180328023535'}
# {'scandate': '20180608000756'}
# {'donor': 'bostonpubliclibrary'}
# {'scandate': '20180911073301'}
# {'scandate': '20181115060936'}
# {'scandate': '20180902212115'}
# {'scandate': '20180921121028'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170719154127'}
# {'scandate': '20180111130932'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161108123712', 'shipping_container': 'SZ0023'}
# {'scandate': '20190114170926'}
# {'scandate': '20180523221318'}
# {'donor': 'allen_county', 'scandate': '20170810155146', 'shipping_container': 'SZ0025'}
# {'scandate': '20190108091253'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180120212519'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180118223127'}
# {'scandate': '20180110081341'}
# {'scandate': '20180804033546'}
# {'donor': 'alibris', 'scandate': '20180121211922'}
# {'scandate': '20180613030317'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161119061903', 'shipping_container': 'SZ0023'}
# {'scandate': '20190108060923'}
# {'donor': 'bwb', 'scandate': '20180425152637'}
# {'donor': 'bwb', 'scandate': '20160707063250', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160801205349', 'shipping_container': 'SZ0024'}
# {'scandate': '20180328193158'}
# {'scandate': '20181030035431'}
# {'donor': 'bwb', 'scandate': '20160706050348', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170714142736'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170110141233', 'shipping_container': 'SZ0023'}
# {'scandate': '20181214104138'}
# {'scandate': '20181012115042'}
# {'scandate': '20190115222127'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161215120849', 'shipping_container': 'SZ0023'}
# {'scandate': '20180910194637'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20180731161245'}
# {'scandate': '20180608183817'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20170817195216', 'shipping_container': 'SZ0025'}
# {'scandate': '20180912191835'}
# {'scandate': '20180807085526'}
# {'scandate': '20181029061205'}
# {'donor': 'blogistics', 'scandate': '20180821085613'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171222122417'}
# {'scandate': '20181006114731'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170921030346'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171204071108'}
# {'donor': 'blogistics', 'scandate': '20180811091250'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20181009071412'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171222094749'}
# {'scandate': '20180911170134'}
# {'scandate': '20180622074837'}
# {'scandate': '20181026185802'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161202144922', 'shipping_container': 'SZ0023'}
# {'scandate': '20180920173638'}
# {'donor': 'blogistics', 'scandate': '20180829164415'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170807132710'}
# {'scandate': '20180526120513'}
# {'scandate': '20190105071913'}
# {'scandate': '20180512105604'}
# {'scandate': '20180430112406'}
# {'scandate': '20180621131642'}
# {'donor': 'bwb', 'scandate': '20171103045723'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170224150826', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170816192538'}
# {'scandate': '20180507145920'}
# {'scandate': '20180511103125'}
# {'scandate': '20190110142101'}
# {'scandate': '20181106060512'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170812175802'}
# {'scandate': '20181017175404'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170209142434', 'shipping_container': 'SZ0023'}
# {'scandate': '20190111105508'}
# {'scandate': '20181124002522'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170611181537', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161209111838', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180813173413'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180817193233'}
# {'scandate': '20180704131628'}
# {'scandate': '20181011082001'}
# {'scandate': '20180208104934'}
# {'scandate': '20181106075730'}
# {'scandate': '20160826144436', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160823130205', 'shipping_container': 'SZ0024'}
# {'scandate': '20181031043922'}
# {'scandate': '20181031101957'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170115075356', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170712051330', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170524213630'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170301103655', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170521132907'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161031093058', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170305090313', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170213104406', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170221104043', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170525204856'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171015205633'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170802015708', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170724115355'}
# {'donor': 'Boston Public', 'scandate': '20160816030912', 'shipping_container': 'SZ0024'}
# {'scandate': '20180209134120'}
# {'scandate': '20180419080439'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161210060108', 'shipping_container': 'SZ0023'}
# {'donor': 'alibris', 'scandate': '20181018164848'}
# {'scandate': '20180307123120'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171224023402'}
# {'scandate': '20181011201756'}
# {'scandate': '20181119152328'}
# {'scandate': '20190110164816'}
# {'scandate': '20181118191017'}
# {'scandate': '20180302072724'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170510113718'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170107051626', 'shipping_container': 'SZ0023'}
# {'scandate': '20181117164506'}
# {'scandate': '20180629113618'}
# {'scandate': '20180831121814'}
# {'scandate': '20180807124536'}
# {'scandate': '20180620072213'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170731192453'}
# {'donor': 'bwb', 'scandate': '20171110015929'}
# {'scandate': '20180313091639'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180112103304'}
# {'scandate': '20180128065808'}
# {'scandate': '20180825095433'}
# {'scandate': '20180311042857'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180827063221'}
# {'donor': 'allen_county', 'scandate': '20170913194152', 'shipping_container': 'SZ0025'}
# {'scandate': '20180630160330'}
# {'donor': 'blogistics', 'scandate': '20180814180553'}
# {'scandate': '20180628055715'}
# {'scandate': '20180507045938'}
# {'donor': 'bwb', 'scandate': '20170705105316', 'shipping_container': 'SZ0025'}
# {'donor': ['Kensington Library', 'internetarchivebookdrive'], 'scandate': '20170330154643', 'shipping_container': 'SZ0024'}
# {'donor': 'bwb', 'scandate': '20171125095208'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171017124035'}
# {'scandate': '20180502103425'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171211162940'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170107122218', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161231041302', 'shipping_container': 'SZ0023'}
# {'scandate': '20181215195810'}
# {'scandate': '20180604131502'}
# {'scandate': '20180603024344'}
# {'donor': 'blogistics', 'scandate': '20130910092729', 'shipping_container': 'SZ0024'}
# {'donor': 'alibris', 'scandate': '20171123114440'}
# {'scandate': '20181030132411'}
# {'scandate': '20180228160222'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171203220157'}
# {'scandate': '20180202062942'}
# {'donor': 'bwb', 'scandate': '20170726154636', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170604074546'}
# {'donor': 'bwb', 'scandate': '20170706112910', 'shipping_container': 'SZ0025'}
# {'scandate': '20180507081603'}
# {'scandate': '20181016065804'}
# {'scandate': '20180921190024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171125055732'}
# {'donor': 'bwb', 'scandate': '20170614033914', 'shipping_container': 'SZ0025'}
# {'donor': 'alibris', 'scandate': '20171119074527'}
# {'scandate': '20181228164036'}
# {'scandate': '20180627053224'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170505204921'}
# {'scandate': '20180504032307'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160719161410', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171205045606'}
# {'scandate': '20180719145608'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171114060718'}
# {'scandate': '20181024173919'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170530065329'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180828005410'}
# {'donor': 'alibris', 'scandate': '20180102024148'}
# {'scandate': '20180915131450'}
# {'scandate': '20180602195927'}
# {'scandate': '20181028150530'}
# {'scandate': '20180301003636'}
# {'scandate': '20180712123020'}
# {'scandate': '20180729081517'}
# {'scandate': '20180602161214'}
# {'scandate': '20180320192221'}
# {'scandate': '20180930135119'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171206224029'}
# {'scandate': '20180223085255'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170703142711', 'shipping_container': 'SZ0025'}
# {'scandate': '20180823051744'}
# {'scandate': '20180513035703'}
# {'scandate': '20181010043800'}
# {'scandate': '20180609093416'}
# {'scandate': '20180222213206'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180813055526'}
# {'scandate': '20180626121732'}
# {'scandate': '20180128014504'}
# {'scandate': '20180531093158'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170313105902', 'shipping_container': 'SZ0023'}
# {'scandate': '20181002182818'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170703121933', 'shipping_container': 'SZ0025'}
# {'scandate': '20180831125826'}
# {'donor': 'alibris', 'scandate': '20171112062141'}
# {'scandate': '20180911184453'}
# {'scandate': '20180827150740'}
# {'scandate': '20180721234848'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170607091914', 'shipping_container': 'SZ0025'}
# {'scandate': '20180710190839'}
# {'scandate': '20180803185649'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170908214144', 'shipping_container': 'SZ0023'}
# {'scandate': '20180213054825'}
# {'scandate': '20180611041254'}
# {'scandate': '20180711112856'}
# {'scandate': '20181011080931'}
# {'scandate': '20181127035249'}
# {'scandate': '20180317125957'}
# {'scandate': '20180517201411'}
# {'scandate': '20180308061155'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161022085016', 'shipping_container': 'SZ0023'}
# {'scandate': '20180614024023'}
# {'scandate': '20180912072536'}
# {'scandate': '20180619231427'}
# {'scandate': '20180519103730'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170810145836'}
# {'scandate': '20190122210851'}
# {'scandate': '20181011143946'}
# {'scandate': '20181115140446'}
# {'scandate': '20180911183419'}
# {'scandate': '20180911121534'}
# {'scandate': '20181213153908'}
# {'scandate': '20181117141632'}
# {'scandate': '20181105141931'}
# {'scandate': '20180326170939'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161212104939', 'shipping_container': 'SZ0023'}
# {'donor': ['Kensington Library', 'internetarchivebookdrive'], 'scandate': '20160629024234', 'shipping_container': 'SZ0024'}
# {'scandate': '20181012092313'}
# {'scandate': '20180704082132'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20170818192531'}
# {'scandate': '20180904165028'}
# {'scandate': '20190107002540'}
# {'scandate': '20180711212351'}
# {'scandate': '20181003212806'}
# {'scandate': '20181011144858'}
# {'scandate': '20170326172351', 'shipping_container': 'SZ0024'}
# {'scandate': '20180713053610'}
# {'scandate': '20181022114623'}
# {'scandate': '20180929033156'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170429041033'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180818042612'}
# {'scandate': '20180420100712'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170604130831', 'shipping_container': 'SZ0025'}
# {'scandate': '20180329012812'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170603080256'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20180806041535'}
# {'scandate': '20180831111207'}
# {'scandate': '20180522195643'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170922024150', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170205075645', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180103053504'}
# {'donor': 'alibris', 'scandate': '20180804022159'}
# {'scandate': '20180814072522'}
# {'scandate': '20180313055820'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180120191313'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171212183157'}
# {'scandate': '20180731070644'}
# {'scandate': '20181204021534'}
# {'scandate': '20180914154921'}
# {'scandate': '20180713050237'}
# {'scandate': '20180627074019'}
# {'scandate': '20180307025508'}
# {'scandate': '20180417171424'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180104161959'}
# {'scandate': '20180626085533'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161205042547', 'shipping_container': 'SZ0023'}
# {'scandate': '20180714113247'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180119212623'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160702171448', 'shipping_container': 'SZ0024'}
# {'scandate': '20181018122808'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170715131556', 'shipping_container': 'SZ0025'}
# {'scandate': '20181101135703'}
# {'scandate': '20180608170044'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170510040704'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171227062737'}
# {'scandate': '20180707205119'}
# {'scandate': '20180305142022'}
# {'scandate': '20180918083223'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170711094011', 'shipping_container': 'SZ0025'}
# {'donor': 'alibris', 'scandate': '20170606013141'}
# {'scandate': '20180520090658'}
# {'scandate': '20180109020030'}
# {'donor': 'allen_county', 'scandate': '20171227060624'}
# {'scandate': '20181129090051'}
# {'scandate': '20181011121054'}
# {'scandate': '20180223123353'}
# {'scandate': '20180808124541'}
# {'scandate': '20180727084411'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180112063712'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180809205554'}
# {'scandate': '20180202103336'}
# {'scandate': '20181030180323'}
# {'donor': 'alibris', 'scandate': '20171112065148'}
# {'scandate': '20180223075430'}
# {'scandate': '20180208074430'}
# {'scandate': '20180731022755'}
# {'donor': 'allen_county', 'scandate': '20170625132429', 'shipping_container': 'SZ0025'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171111115722'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170317101110', 'shipping_container': 'SZ0024'}
# {'scandate': '20180925115509'}
# {'donor': 'bostonpubliclibrarydonation', 'scandate': '20160824104657', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170605042558'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170224033802', 'shipping_container': 'SZ0024'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171220003607'}
# {'scandate': '20180201043943'}
# {'scandate': '20181129135330'}
# {'scandate': '20180724200526'}
# {'scandate': '20180321082810'}
# {'scandate': '20180924045646'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171110072903'}
# {'donor': 'blogistics', 'scandate': '20180813183340'}
# {'scandate': '20180911190641'}
# {'scandate': '20180608153957'}
# {'scandate': '20180317053547'}
# {'donor': 'alibris', 'scandate': '20171221071210'}
# {'scandate': '20180419164602'}
# {'scandate': '20181009165618'}
# {'donor': 'blogistics', 'scandate': '20180813043313'}
# {'scandate': '20180405194323'}
# {'scandate': '20181002213245'}
# {'scandate': '20180606235519'}
# {'scandate': '20180125050412'}
# {'scandate': '20190112081838'}
# {'donor': 'alibris', 'scandate': '20180723081228'}
# {'scandate': '20181030063918'}
# {'donor': 'bwb', 'scandate': '20160711105904', 'shipping_container': 'SZ0024'}
# {'donor': 'alibris', 'scandate': '20180818150036'}
# {'scandate': '20180210101046'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170608075709', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171011104624'}
# {'scandate': '20181010115029'}
# {'scandate': '20180805160015'}
# {'scandate': '20181010214446'}
# {'scandate': '20180307143535'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170123055642', 'shipping_container': 'SZ0023'}
# {'scandate': '20180328034727'}
# {'scandate': '20180319014447'}
# {'scandate': '20181231123819'}
# {'scandate': '20180607073538'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171116092219'}
# {'scandate': '20180509024727'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20171111190853'}
# {'scandate': '20180504151535'}
# {'scandate': '20181022165941'}
# {'scandate': '20181008091939'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171012130759'}
# {'scandate': '20181017035802'}
# {'scandate': '20180929105205'}
# {'scandate': '20180327194527'}
# {'scandate': '20180825122026'}
# {'scandate': '20181018070944'}
# {'scandate': '20180506084236'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161217051400', 'shipping_container': 'SZ0023'}
# {'scandate': '20180731174733'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170830113744'}
# {'scandate': '20181024083336'}
# {'scandate': '20181105200551'}
# {'scandate': '20181226135849'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171220224921'}
# {'scandate': '20180623013131'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170222132627', 'shipping_container': 'SZ0025'}
# {'scandate': '20180719133731'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171120082220'}
# {'scandate': '20181130071909'}
# {'scandate': '20180511161820'}
# {'scandate': '20180517075827'}
# {'scandate': '20180809183742'}
# {'scandate': '20180324032713'}
# {'scandate': '20181112071612'}
# {'scandate': '20180625154352'}
# {'scandate': '20190108044904'}
# {'scandate': '20181123121040'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171227061653'}
# {'donor': 'allen_county', 'scandate': '20170815012952'}
# {'scandate': '20180126181116'}
# {'scandate': '20180713100400'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170525055047'}
# {'scandate': '20181121040956'}
# {'scandate': '20180808141228'}
# {'scandate': '20180125125805'}
# {'scandate': '20180406073013'}
# {'scandate': '20181230091039'}
# {'scandate': '20181112185506'}
# {'scandate': '20180909120039'}
# {'scandate': '20190106120606'}
# {'scandate': '20181011143733'}
# {'scandate': '20180508051625'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180814145236'}
# {'scandate': '20180514135730'}
# {'scandate': '20180209025808'}
# {'scandate': '20181130105616'}
# {'donor': 'bwb', 'scandate': '20171107112107'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180112103203'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180122191842'}
# {'scandate': '20180321190741'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160812190828', 'shipping_container': 'SZ0024'}
# {'donor': 'bwb', 'scandate': '20170628173717', 'shipping_container': 'SZ0025'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171130174356'}
# {'scandate': '20180726125312'}
# {'scandate': '20180205155935'}
# {'scandate': '20181203145330'}
# {'scandate': '20180411065007'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180105195636'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161220080811', 'shipping_container': 'SZ0023'}
# {'donor': 'bwb', 'scandate': '20170310093718', 'shipping_container': 'SZ0024'}
# {'scandate': '20181123153214'}
# {'scandate': '20180605185934'}
# {'scandate': '20180918165541'}
# {'scandate': '20180604075641'}
# {'scandate': '20180721175734'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161125091542', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171110034214'}
# {'scandate': '20180706124728'}
# {'donor': 'alibris', 'scandate': '20170414141116'}
# {'scandate': '20180523094610'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171215191942'}
# {'scandate': '20180727180052'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180822200132'}
# {'donor': 'allen_county', 'scandate': '20170928150730', 'shipping_container': 'SZ0025'}
# {'scandate': '20181101175220'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171212110638'}
# {'scandate': '20180809090239'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161226134559', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161227082032', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161123032835', 'shipping_container': 'SZ0023'}
# {'scandate': '20181016150108'}
# {'scandate': '20181106064412'}
# {'donor': 'allen_county', 'scandate': '20170905111453'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180105130242'}
# {'scandate': '20180313103938'}
# {'donor': 'alibris', 'scandate': '20171203201739'}
# {'scandate': '20180202234104'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20170122230608', 'shipping_container': 'SZ0023'}
# {'scandate': '20180914091257'}
# {'scandate': '20180223065143'}
# {'scandate': '20180524233410'}
# {'scandate': '20180622130535'}
# {'scandate': '20181122171559'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20181017090331'}
# {'scandate': '20181010154916'}
# {'donor': 'bwb', 'scandate': '20170321164734', 'shipping_container': 'SZ0024'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180723173817'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180114104708'}
# {'scandate': '20181225232801'}
# {'scandate': '20180618045423'}
# {'scandate': '20180627125644'}
# {'scandate': '20181116072714'}
# {'scandate': '20181011132504'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170904061104'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170828053129'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180126000446'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180117025439'}
# {'scandate': '20181024052341'}
# {'scandate': '20180210081319'}
# {'scandate': '20181026230604'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170925190611', 'shipping_container': 'SZ0025'}
# {'scandate': '20180714062526'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171111080416', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180802092722'}
# {'scandate': '20180827152523'}
# {'scandate': '20180328062428'}
# {'donor': ['Kensington Library', 'internetarchivebookdrive'], 'scandate': '20160625140354', 'shipping_container': 'SZ0024'}
# {'scandate': '20180829094312'}
# {'scandate': '20181201150920'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180121061543'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180104130103'}
# {'scandate': '20180227052603'}
# {'scandate': '20180817013001'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170319094759', 'shipping_container': 'SZ0023'}
# {'scandate': '20181111175333'}
# {'scandate': '20180315070309'}
# {'scandate': '20180410105415'}
# {'donor': 'bwb', 'scandate': '20170706112102', 'shipping_container': 'SZ0025'}
# {'donor': 'allen_county', 'scandate': '20170824142921'}
# {'scandate': '20180525094239'}
# {'donor': 'bwb', 'scandate': '20170314114057', 'shipping_container': 'SZ0024'}
# {'scandate': '20180319053342'}
# {'scandate': '20180206124317'}
# {'scandate': '20181228232710'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180116210621'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171123042628'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20170512191331'}
# {'scandate': '20180504033513'}
# {'scandate': '20180131211111'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161125042714', 'shipping_container': 'SZ0023'}
# {'scandate': '20180128160630'}
# {'scandate': '20180904164708'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171120220211'}
# {'scandate': '20180201105248'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171215193833'}
# {'donor': 'blogistics', 'scandate': '20180831121542'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160702043234', 'shipping_container': 'SZ0024'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20170527151644'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170813162329'}
# {'scandate': '20180927125414'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161015085147', 'shipping_container': 'SZ0023'}
# {'scandate': '20181113095524'}
# {'scandate': '20180204072049'}
# {'scandate': '20180110064443'}
# {'scandate': '20180603094111'}
# {'scandate': '20181221023622'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180822093006'}
# {'scandate': '20181204132112'}
# {'scandate': '20180925130729'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171122091655'}
# {'scandate': '20181213045142'}
# {'scandate': '20181008082535'}
# {'scandate': '20180913040945'}
# {'scandate': '20180803185448'}
# {'scandate': '20181013075358'}
# {'scandate': '20181013112422'}
# {'scandate': '20181126163156'}
# {'donor': 'allen_countydonation', 'scandate': '20170510070947'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171029101904'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161201075242', 'shipping_container': 'SZ0023'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20130813021846', 'shipping_container': 'SZ0024'}
# {'donor': 'alibris', 'scandate': '20180726133836'}
# {'donor': 'alibris', 'scandate': '20180726105518'}
# {'scandate': '20180430090513'}
# {'scandate': '20181128160023'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20170410054714', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrarydonation', 'scandate': '20170403151713', 'shipping_container': 'SZ0024'}
# {'scandate': '20180430203341'}
# {'scandate': '20190104204543'}
# {'scandate': '20190114103112'}
# {'scandate': '20181116083512'}
# {'scandate': '20180717140613'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170822102658'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171124034728'}
# {'scandate': '20180714095620'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160819095903', 'shipping_container': 'SZ0024'}
# {'donor': 'allen_county', 'scandate': '20170620070930', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170912053404', 'shipping_container': 'SZ0025'}
# {'scandate': '20180807103942'}
# {'scandate': '20181121155706'}
# {'donor': 'alibris', 'scandate': '20160606134523', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180122065826'}
# {'scandate': '20180907090757'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161010134657', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170824134406'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171029123446'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180131193618'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161029080149', 'shipping_container': 'SZ0023'}
# {'scandate': '20180730064454'}
# {'scandate': '20181226095956'}
# {'scandate': '20180821101131'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161021041242', 'shipping_container': 'SZ0023'}
# {'scandate': '20180801204804'}
# {'scandate': '20180320043420'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171117132033'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20130906083622', 'shipping_container': 'SZ0024'}
# {'scandate': '20181205174552'}
# {'scandate': '20180509120232'}
# {'scandate': '20180630114129'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170113071005', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161220091327', 'shipping_container': 'SZ0023'}
# {'scandate': '20180305023935'}
# {'scandate': '20180908123923'}
# {'scandate': '20180519200924'}
# {'scandate': '20180718113552'}
# {'scandate': '20180811102305'}
# {'donor': 'Boston Public', 'scandate': '20170608034724'}
# {'scandate': '20180515152506'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170819124115'}
# {'scandate': '20180623072053'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170224032620', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161212104648', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161209170325', 'shipping_container': 'SZ0023'}
# {'scandate': '20180716201916'}
# {'scandate': '20180314105035'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170928015416', 'shipping_container': 'SZ0025'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20170427054049'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20171117045447'}
# {'scandate': '20180505050328'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161205073850', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161115063941', 'shipping_container': 'SZ0023'}
# {'scandate': '20180928123326'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171222132013'}
# {'donor': 'blogistics', 'scandate': '20171013162500'}
# {'scandate': '20180924090337'}
# {'scandate': '20180715052413'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180118035546'}
# {'scandate': '20190109143011'}
# {'scandate': '20181124190738'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171114133059'}
# {'scandate': '20180317114801'}
# {'scandate': '20190110112944'}
# {'donor': 'Boston Public', 'scandate': '20161010100822', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160823042228', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170327161248', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161219173816', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161130155133', 'shipping_container': 'SZ0023'}
# {'scandate': '20180911080944'}
# {'scandate': '20180706225220'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160807005502', 'shipping_container': 'SZ0024'}
# {'scandate': '20181024041436'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170817053632'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161124092142', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180105052528'}
# {'scandate': '20180127093000'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161124091723', 'shipping_container': 'SZ0023'}
# {'scandate': '20181016120508'}
# {'scandate': '20181121210308'}
# {'scandate': '20181013162616'}
# {'scandate': '20181021155701'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170218005338', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170706135422', 'shipping_container': 'SZ0025'}
# {'scandate': '20180926123549'}
# {'scandate': '20190104165931'}
# {'scandate': '20181221172716'}
# {'scandate': '20190110031226'}
# {'scandate': '20180627064810'}
# {'scandate': '20180611215132'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170320184740', 'shipping_container': 'SZ0023'}
# {'scandate': '20181127152100'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171123041812'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170608211919', 'shipping_container': 'SZ0025'}
# {'scandate': '20181101164455'}
# {'scandate': '20180327064306'}
# ...
# {'scandate': '20180727034047'}
# {'scandate': '20180210064158'}
# {'scandate': '20180725031634'}
# {'scandate': '20180711073509'}
# {'scandate': '20180125035602'}
# {'scandate': '20180412072104'}
# {'scandate': '20180119064608'}
# {'scandate': '20171229085746'}
# {'scandate': '20180403065844'}
# {'scandate': '20171030134533'}
# {'scandate': '20180318040959'}
# {'scandate': '20180124111707'}
# {'scandate': '20181016042340'}
# {'scandate': '20180521051502'}
# {'scandate': '20180813035002'}
# {'scandate': '20181017115026'}
# {'scandate': '20180129113108'}
# {'scandate': '20180911055033'}
# {'scandate': '20181207080814'}
# {'scandate': '20180105104854'}
# {'scandate': '20171122040111'}
# {'scandate': '20180614102653'}
# {'scandate': '20171228083138'}
# {'scandate': '20171206104457'}
# {'scandate': '20180827043837'}
# {'scandate': '20181204095519'}
# {'scandate': '20180829052850'}
# {'scandate': '20180123134038'}
# {'scandate': '20180911041224'}
# {'scandate': '20180210033328'}
# {'scandate': '20180211062653'}
# {'scandate': '20180203084201'}
# {'scandate': '20180131062919'}
# {'scandate': '20180716091520'}
# {'scandate': '20180323050036'}
# {'scandate': '20180124122605'}
# {'scandate': '20180303074751'}
# {'scandate': '20180105114442'}
# {'scandate': '20180624032200'}
# {'scandate': '20180514051050'}
# {'scandate': '20180130042912'}
# {'scandate': '20171019060857'}
# {'scandate': '20181105044414'}
# {'scandate': '20180105122832'}
# {'scandate': '20180213025425'}
# {'scandate': '20171026063226'}
# {'scandate': '20181102053339'}
# {'scandate': '20180909053920'}
# {'scandate': '20180720045806'}
# {'scandate': '20170927044028'}
# {'scandate': '20180123120034'}
# {'scandate': '20171215042851'}
# {'scandate': '20171025093328'}
# {'scandate': '20171120093403'}
# {'scandate': '20180412084928'}
# {'scandate': '20181206042657'}
# {'scandate': '20181006053524'}
# {'scandate': '20180114091809'}
# {'scandate': '20171116015539'}
# {'scandate': '20180118033348'}
# {'scandate': '20180729044940'}
# {'scandate': '20180528033126'}
# {'scandate': '20171103045707'}
# {'scandate': '20171215073838'}
# {'scandate': '20180712074337'}
# {'scandate': '20171020043209'}
# {'scandate': '20180428034015'}
# {'scandate': '20180625073339'}
# {'scandate': '20180522080634'}
# {'scandate': '20180822061602'}
# {'scandate': '20180223041815'}
# {'scandate': '20181029135912'}
# {'scandate': '20180619083654'}
# {'scandate': '20180726090428'}
# {'scandate': '20170817080909'}
# {'scandate': '20180825045451'}
# {'scandate': '20180430024941'}
# {'scandate': '20180831084046'}
# {'scandate': '20180807084732'}
# {'scandate': '20170924034932'}
# {'scandate': '20181219080509'}
# {'scandate': '20180611080504'}
# {'scandate': '20171116082407'}
# {'scandate': '20181028044333'}
# {'scandate': '20181105120923'}
# {'scandate': '20171024065922'}
# {'scandate': '20180914101806'}
# {'scandate': '20180204091644'}
# {'scandate': '20180812012307'}
# {'scandate': '20180410050225'}
# {'scandate': '20180918054315'}
# {'scandate': '20171228122426'}
# {'scandate': '20181112021209'}
# {'scandate': '20180325092927'}
# {'scandate': '20180706030016'}
# {'scandate': '20180808040654'}
# {'scandate': '20180516133811'}
# {'scandate': '20180606032111'}
# {'scandate': '20180228022952'}
# {'scandate': '20180825090050'}
# {'scandate': '20180310052953'}
# {'scandate': '20180524025452'}
# {'scandate': '20181028082137'}
# {'scandate': '20180402074114'}
# {'scandate': '20180423040130'}
# {'scandate': '20170922114244'}
# {'scandate': '20180614050939'}
# {'scandate': '20180511055350'}
# {'scandate': '20180828075934'}
# {'scandate': '20180529093148'}
# {'scandate': '20181110042416'}
# {'scandate': '20180409022756'}
# {'scandate': '20180410082700'}
# {'scandate': '20171222024837'}
# {'scandate': '20180601033416'}
# {'scandate': '20180729052954'}
# {'scandate': '20181120093802'}
# {'scandate': '20180503072700'}
# {'scandate': '20180125074909'}
# {'scandate': '20180705032339'}
# {'scandate': '20180225002711'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161230131420', 'shipping_container': 'SZ0023'}
# {'scandate': '20181110135807'}
# {'scandate': '20180512031812'}
# {'scandate': '20180723034932'}
# {'scandate': '20180731200941'}
# {'scandate': '20180406190321'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170207161011', 'shipping_container': 'SZ0025'}
# {'scandate': '20181106172355'}
# {'scandate': '20180720051835'}
# {'scandate': '20180526012838'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170422061835', 'shipping_container': 'SZ0024'}
# {'scandate': '20181120201605'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170622141328', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171025111850', 'shipping_container': 'SZ0024'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171107042134'}
# {'donor': 'blogistics', 'scandate': '20170926071717'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170223091646', 'shipping_container': 'SZ0025'}
# {'scandate': '20181110180243'}
# {'scandate': '20180304172936'}
# {'scandate': '20180601042918'}
# {'scandate': '20181119035857'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170123090606', 'shipping_container': 'SZ0023'}
# {'donor': 'bwb', 'scandate': '20170404152359', 'shipping_container': 'SZ0024'}
# {'scandate': '20180210163149'}
# {'donor': 'alibris', 'scandate': '20180821113451'}
# {'scandate': '20180601043920'}
# {'scandate': '20180206095209'}
# {'scandate': '20180809122527'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170116083937', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20181103085800'}
# {'donor': 'blogistics', 'scandate': '20180109034446'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170721051423', 'shipping_container': 'SZ0025'}
# {'scandate': '20181106213513'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161129093650', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171013055229'}
# {'scandate': '20180911194057'}
# {'scandate': '20180510143030'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161011102356', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161012053249', 'shipping_container': 'SZ0023'}
# {'scandate': '20180809041524'}
# {'donor': 'allen_county', 'scandate': '20170925084315', 'shipping_container': 'SZ0025'}
# {'scandate': '20181227144541'}
# {'scandate': '20190115102115'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170810191236'}
# {'scandate': '20180411055245'}
# {'scandate': '20190117124530'}
# {'scandate': '20180512101407'}
# {'scandate': '20180122182203'}
# {'scandate': '20180525013809'}
# {'scandate': '20181109212655'}
# {'scandate': '20180131004511'}
# {'scandate': '20180202061805'}
# {'scandate': '20180827063131'}
# {'scandate': '20180724230323'}
# {'scandate': '20180206135441'}
# {'donor': 'cityofsausalitolibrary', 'scandate': '20180726063400'}
# {'scandate': '20181106064619'}
# {'scandate': '20190103131242'}
# {'scandate': '20180326211205'}
# {'scandate': '20180428110816'}
# {'scandate': '20180409095946'}
# {'scandate': '20180622170120'}
# {'scandate': '20181026191146'}
# {'donor': 'bwb', 'scandate': '20171110050919'}
# {'scandate': '20180602064938'}
# {'scandate': '20180711212708'}
# {'donor': 'bwb', 'scandate': '20170609115717', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180127144608'}
# {'scandate': '20180520215650'}
# {'scandate': '20181013063411'}
# {'scandate': '20180304150652'}
# {'scandate': '20180507073622'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170921154617', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrarydonation', 'scandate': '20170321125313', 'shipping_container': 'SZ0024'}
# {'scandate': '20180919182012'}
# {'scandate': '20181003190303'}
# {'scandate': '20180521063614'}
# {'scandate': '20180202114543'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20180827105452'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180808150908'}
# {'scandate': '20180423173932'}
# {'scandate': '20180402235230'}
# {'scandate': '20180419155616'}
# {'scandate': '20190102113042'}
# {'scandate': '20180315110242'}
# {'scandate': '20180710193019'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170809181238', 'shipping_container': 'SZ0025'}
# {'scandate': '20180721175204'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171116213003'}
# {'donor': 'bwb', 'scandate': '20170324165300', 'shipping_container': 'SZ0024'}
# {'scandate': '20180227221102'}
# {'scandate': '20180416060149'}
# {'donor': 'alibris', 'scandate': '20180831020216'}
# {'scandate': '20181106154518'}
# {'scandate': '20180520060254'}
# {'scandate': '20180213053020'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170309103141', 'shipping_container': 'SZ0024'}
# {'scandate': '20180625152530'}
# {'donor': 'bwb', 'scandate': '20171107033734'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170531120835'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20171115210816'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20180815063531'}
# {'donor': 'bwb', 'scandate': '20171031235437'}
# {'donor': 'alibris', 'scandate': '20180729183802'}
# {'scandate': '20180416060534'}
# {'scandate': '20190101174901'}
# {'scandate': '20181012145618'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170513195817'}
# {'scandate': '20180806065320'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180904134020'}
# {'scandate': '20180517184456'}
# {'scandate': '20180611093053'}
# {'scandate': '20180414064654'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170601124756'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170106075455', 'shipping_container': 'SZ0023'}
# {'scandate': '20181003234516'}
# {'scandate': '20180208101918'}
# {'scandate': '20181025093702'}
# {'scandate': '20180831151730'}
# {'scandate': '20181207103339'}
# {'scandate': '20190115065352'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180105201901'}
# {'scandate': '20180815092237'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180128183026'}
# {'scandate': '20180612174942'}
# {'scandate': '20181122114342'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20180206165449'}
# {'scandate': '20180720001424'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170114113126', 'shipping_container': 'SZ0023'}
# {'scandate': '20180206145350'}
# {'donor': 'bwb', 'scandate': '20170311115417', 'shipping_container': 'SZ0024'}
# {'scandate': '20180123110406'}
# {'scandate': '20180629060231'}
# {'scandate': '20181119094842'}
# {'scandate': '20180715101448'}
# {'scandate': '20180827122134'}
# {'scandate': '20180430071933'}
# {'scandate': '20180221151538'}
# {'donor': 'allen_county', 'scandate': '20170513232158'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170814152125'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20171121210023'}
# {'scandate': '20181101102036'}
# {'scandate': '20190120140708'}
# {'scandate': '20180519021229'}
# {'scandate': '20180207111639'}
# {'scandate': '20180205131546'}
# {'scandate': '20180208080439'}
# {'scandate': '20180912042844'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170826121911'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170921143748', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170117114323', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170305171601', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170303071534', 'shipping_container': 'SZ0023'}
# {'donor': 'Boston Public', 'scandate': '20170305044008', 'shipping_container': 'SZ0023'}
# {'scandate': '20180224183821'}
# {'scandate': '20181117054034'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171001075749', 'shipping_container': 'SZ0023'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171213001619'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20181016151924'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161221082610', 'shipping_container': 'SZ0023'}
# {'donor': 'bwb', 'scandate': '20170524232616'}
# {'scandate': '20180703043530'}
# {'donor': 'bwb', 'scandate': '20170402174607', 'shipping_container': 'SZ0024'}
# {'scandate': '20180327062132'}
# {'scandate': '20181121115000'}
# {'scandate': '20181213194320'}
# {'scandate': '20180707220947'}
# {'scandate': '20180210025213'}
# {'scandate': '20181006125131'}
# {'scandate': '20181105125748'}
# {'scandate': '20180626194801'}
# {'scandate': '20180804191759'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170113061147', 'shipping_container': 'SZ0023'}
# {'scandate': '20180611045142'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170112083542', 'shipping_container': 'SZ0023'}
# {'scandate': '20180201030823'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170917005123', 'shipping_container': 'SZ0025'}
# {'scandate': '20180515072901'}
# {'scandate': '20180729082147'}
# {'scandate': '20190111134056'}
# {'scandate': '20180805221738'}
# {'scandate': '20180228102024'}
# {'scandate': '20180326192905'}
# {'scandate': '20180908163032'}
# {'scandate': '20180618115408'}
# {'scandate': '20180623224647'}
# {'scandate': '20180223100159'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160819125924', 'shipping_container': 'SZ0024'}
# {'scandate': '20180627103723'}
# {'scandate': '20181025153828'}
# {'scandate': '20180415054418'}
# {'scandate': '20180308113347'}
# {'scandate': '20181107165217'}
# {'scandate': '20181021162713'}
# {'donor': 'friendsofthesanfranciscopubliclibrary', 'scandate': '20170922083133'}
# {'scandate': '20181022071016'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20171223070302'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171206080919'}
# {'scandate': '20181031090009'}
# {'donor': 'sanrafaelpubliclibrary', 'scandate': '20170211110806', 'shipping_container': 'SZ0025'}
# {'donor': 'alibris', 'scandate': '20180817203720'}
# {'scandate': '20181207055409'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170812102428', 'shipping_container': 'SZ0025'}
# {'scandate': '20181007174148'}
# {'donor': 'bwb', 'scandate': '20171110185426'}
# {'donor': 'bwb', 'scandate': '20170324110106', 'shipping_container': 'SZ0024'}
# {'scandate': '20180510100240'}
# {'scandate': '20180210044754'}
# {'scandate': '20181001034202'}
# {'scandate': '20180807002156'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170825162132'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170907075722'}
# {'scandate': '20181203044727'}
# {'scandate': '20181115104707'}
# {'scandate': '20180301183948'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171027004252', 'shipping_container': 'SZ0023'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20170122030942', 'shipping_container': 'SZ0024'}
# {'scandate': '20180712075759'}
# {'scandate': '20180324072249'}
# {'scandate': '20181204132024'}
# {'scandate': '20181106104920'}
# {'scandate': '20180617135125'}
# {'scandate': '20180425105454'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20161231034439', 'shipping_container': 'SZ0023'}
# {'scandate': '20180720201407'}
# {'scandate': '20190112023856'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170508161022'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171205172823'}
# {'donor': 'internetarchivebookdrive', 'scandate': '20161208153204', 'shipping_container': 'SZ0023'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170309072122', 'shipping_container': 'SZ0024'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20171114071833'}
# {'donor': 'alibris', 'scandate': '20170509233826'}
# {'donor': 'allen_county', 'scandate': '20171010142703', 'shipping_container': 'SZ0025'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20160817043753', 'shipping_container': 'SZ0024'}
# {'scandate': '20180312083718'}
# {'scandate': '20180705070859'}
# {'scandate': '20180714141605'}
# {'scandate': '20180414185831'}
# {'donor': 'bostonpubliclibrary', 'scandate': '20170430081750'}
# {'scandate': '20181107112925'}
# {'scandate': '20180504210058'}
# {'scandate': '20180205025344'}
# {'scandate': '20180919142536'}
# {'donor': 'burlingamepubliclibrary', 'scandate': '20171123132633'}
# {'scandate': '20180803020614'}
# {'scandate': '20181011142528'}
# {'scandate': '20180413103832'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(refac_hk)
# Out:
# 480736

# %%
hongkong_df = pd.DataFrame(refac_hk)

# %%
hongkong_df
# Out:
#                                         donor        scandate  \
# 0                                  blogistics  20180724133739
# 1                                         NaN  20180611023417
# 2                                         NaN  20181224163053
# 3                    internetarchivebookdrive  20180813120333
# 4                         bostonpubliclibrary  20180818203457
# ...                                       ...             ...
# 480731                                    NaN  20190111110720
# 480732            bostonpubliclibrarydonation  20170311111204
# 480733                                    NaN  20181204170115
# 480734  friendsofthesanfranciscopubliclibrary  20180825215354
# 480735                                    NaN  20181012013034
#
#        shipping_container
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 480731                NaN
# 480732             SZ0024
# 480733                NaN
# 480734                NaN
# 480735                NaN
#
# [480736 rows x 3 columns]

# %%
hongkong_df['donor'].unique().tolist()
# Out:
# ['blogistics',
#  nan,
#  'internetarchivebookdrive',
#  'bostonpubliclibrary',
#  'bwb',
#  'alibris',
#  'allen_county',
#  'bostonpubliclibrarydonation',
#  'burlingamepubliclibrary',
#  'belvederetiburonlibrary',
#  'friendsofthesanfranciscopubliclibrary',
#  'cityofsausalitolibrary',
#  'sanrafaelpubliclibrary',
#  'Boston Public',
#  'marincountyfreelibrary',
#  'Peninsula Library System',
#  'allen_countydonation',
#  "['Kensington Library', 'internetarchivebookdrive']",
#  'Book Drive',
#  "['nclivedonation', 'unclibrariesdonation']",
#  'Allen County Public',
#  'San Mateo Public',
#  'Tony Meadows',
#  'Belvedere Tiburon Library',
#  'Vermont Public',
#  'San Rafael Public Library',
#  'Better World Books',
#  "['Belvedere Tiburon Library', 'archbishopmittyhs']",
#  "['internetarchivebookdrive', 'hammsam']",
#  'recycledrecords']

# %%
bpl = hongkong_df.loc[hongkong_df['donor'] == 'bostonpubliclibrary']

# %%
bpl['scandate'] = pd.to_datetime(bpl['scandate'], format='%Y%m%d%H%M%S', errors="coerce")
# Out:
# /var/folders/pl/rjmtml311bq31fb0njd03xlh0000gn/T/ipykernel_17104/1513831781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bpl['scandate'] = pd.to_datetime(bpl['scandate'], format='%Y%m%d%H%M%S', errors="coerce")

# %%
bpl['month_year'] = pd.to_datetime(bpl['scandate']).dt.to_period('M')
# Out:
# /var/folders/pl/rjmtml311bq31fb0njd03xlh0000gn/T/ipykernel_17104/831489136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bpl['month_year'] = pd.to_datetime(bpl['scandate']).dt.to_period('M')

# %%
bpl
bpl_scan_counts = bpl.groupby(bpl['month_year']).count().reset_index()

bpl_scan_counts.astype('str')
# Out:
#    month_year donor scandate shipping_container
# 0     2011-10     1        1                  0
# 1     2011-12     1        1                  0
# 2     2012-02     1        1                  0
# 3     2012-08     1        1                  1
# 4     2013-06     2        2                  2
# 5     2013-08    16       16                 15
# 6     2013-09    90       90                 90
# 7     2014-06     1        1                  0
# 8     2015-09     1        1                  1
# 9     2015-10     1        1                  1
# 10    2015-11     1        1                  0
# 11    2016-02     1        1                  0
# 12    2016-06   586      586                580
# 13    2016-07   870      870                869
# 14    2016-08  2149     2149               2139
# 15    2016-09   170      170                170
# 16    2016-10  1495     1495               1491
# 17    2016-11  1591     1591               1589
# 18    2016-12  4111     4111               4111
# 19    2017-01  3102     3102               3102
# 20    2017-02  2870     2870               2869
# 21    2017-03  2911     2911               2911
# 22    2017-04  1202     1202                490
# 23    2017-05  2182     2182                 29
# 24    2017-06  2606     2606               1924
# 25    2017-07  3439     3439               1270
# 26    2017-08  4893     4893                152
# 27    2017-09  3631     3631               1507
# 28    2017-10  1911     1911               1253
# 29    2017-11  5532     5532                 96
# 30    2017-12  4298     4298                 12
# 31    2018-01  5281     5281                 93
# 32    2018-02   623      623                 36
# 33    2018-03   243      243                  5
# 34    2018-04   317      317                  9
# 35    2018-05   268      268                  3
# 36    2018-06   161      161                132
# 37    2018-07   388      388                232
# 38    2018-08  2995     2995                 10
# 39    2018-09   155      155                  2
# 40    2018-10   362      362                 13
# 41    2018-11    57       57                  1
# 42    2018-12    12       12                  2
# 43    2019-01    35       35                  0

# %%
alt.Chart(bpl_scan_counts.astype('str')).mark_line().encode(
    x='month_year:T',
    y='donor:Q'
)
# Out:
# /Users/elizabethschwartz/opt/anaconda3/envs/DataViz/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
import numpy as np
hongkong_df.loc[hongkong_df['donor'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [donor, scandate, shipping_container]
# Index: []

# %%
hongkong_df
# Out:
#                                         donor        scandate  \
# 0                                  blogistics  20180724133739
# 1                                         NaN  20180611023417
# 2                                         NaN  20181224163053
# 3                    internetarchivebookdrive  20180813120333
# 4                         bostonpubliclibrary  20180818203457
# ...                                       ...             ...
# 480731                                    NaN  20190111110720
# 480732            bostonpubliclibrarydonation  20170311111204
# 480733                                    NaN  20181204170115
# 480734  friendsofthesanfranciscopubliclibrary  20180825215354
# 480735                                    NaN  20181012013034
#
#        shipping_container
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 480731                NaN
# 480732             SZ0024
# 480733                NaN
# 480734                NaN
# 480735                NaN
#
# [480736 rows x 3 columns]

# %%
hongkong_df['scandate'] = pd.to_datetime(hongkong_df['scandate'], format='%Y%m%d%H%M%S', errors="coerce")

hongkong_df['month_year'] = pd.to_datetime(hongkong_df['scandate']).dt.to_period('M')

hongkong_df = hongkong_df.fillna('unknown')

# %%
hongkong_df
hk_scans_per_donor = hongkong_df.groupby(['donor', 'month_year']).count().reset_index()

# %%
alt.Chart(hk_scans_per_donor.astype('str')).mark_bar().encode(
    x='yearmonth(month_year):T',
    y='scandate:Q',
    color= 'donor:N',
    tooltip = ['donor:N', 'month_year:T', 'scandate:Q']
).interactive()
# Out:
# /Users/elizabethschwartz/opt/anaconda3/envs/DataViz/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
hk_scans_per_donor.loc[hk_scans_per_donor['donor'] != 'unknown']

known_donors = alt.Chart(hk_scans_per_donor.loc[hk_scans_per_donor['donor'] != 'unknown'].astype('str')).mark_bar().encode(
    x=alt.X('yearmonth(month_year):T', axis=alt.Axis(title="Month Scanned")),
    y=alt.Y('scandate:Q', axis=alt.Axis(title="Books Scanned")),
    color= 'donor:N',
    tooltip = ['donor:N', 'month_year:T', 'scandate:Q']
).interactive()

total_donors = alt.Chart(hk_scans_per_donor.astype('str')).mark_bar(color='black').encode(
    x='yearmonth(month_year):T',
    y='scandate:Q',
).interactive()

total_donors + known_donors
# Out:
# alt.LayerChart(...)

# %%
hongkong_df.loc[hongkong_df['donor'] == 'unknown']
# Out:
#           donor             scandate shipping_container month_year
# 1       unknown  2018-06-11 02:34:17            unknown    2018-06
# 2       unknown  2018-12-24 16:30:53            unknown    2018-12
# 6       unknown  2018-06-01 00:25:23            unknown    2018-06
# 7       unknown  2018-11-20 16:33:21            unknown    2018-11
# 9       unknown  2018-09-28 14:10:45            unknown    2018-09
# ...         ...                  ...                ...        ...
# 480724  unknown  2018-11-12 20:43:39            unknown    2018-11
# 480727  unknown  2018-06-24 00:58:45            unknown    2018-06
# 480731  unknown  2019-01-11 11:07:20            unknown    2019-01
# 480733  unknown  2018-12-04 17:01:15            unknown    2018-12
# 480735  unknown  2018-10-12 01:30:34            unknown    2018-10
#
# [345169 rows x 4 columns]

# %%
alt.Chart(hk_scans_per_donor.loc[hk_scans_per_donor['donor'] == 'unknown'].astype('str')).mark_bar().encode(
    x='yearmonth(month_year):T',
    y='scandate:Q',
    color= 'donor:N',
    tooltip = ['donor:N', 'month_year:T', 'scandate:Q']
).interactive()
# Out:
# /Users/elizabethschwartz/opt/anaconda3/envs/DataViz/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
alt.Chart(hk_scans_per_donor.loc[hk_scans_per_donor['donor'] != 'unknown'].astype('str')).mark_bar().encode(
    x='yearmonth(month_year):T',
    y='scandate:Q',
    color= 'donor:N',
    tooltip = ['donor:N', 'month_year:T', 'scandate:Q']
).interactive()
# Out:
# alt.Chart(...)

# %%
known_container = hongkong_df.loc[hongkong_df['shipping_container'] != 'unknown']

# %%
known_donors = hk_scans_per_donor.loc[hk_scans_per_donor['donor'] != 'unknown']
known_donors.to_csv("/Users/elizabethschwartz/Documents/spring_2023/culture_at_scale/ia_infrastructure_proj/hongkong-known-donor-scans.csv")

# %%
pd.read_csv("https://raw.githubusercontent.com/ers6/ia_bols/main/geographic-data/bills-of-lading/combined_ia_bols_manual_dedupe%20-%20deduped_results.csv").keys()
# Out:
# Index(['Unnamed: 0', 'source', 'arrival_date', 'company',
#        'company_location_id', 'company_address', 'company_lat', 'company_lon',
#        'supplier', 'supplier_location_id', 'supplier_address', 'supplier_lat',
#        'supplier_lon', 'quantity', 'weight_kg', 'number_containers',
#        'goods_shipped', 'container_marks', 'container_size', 'container_type',
#        'hs_code_detail', 'bol', 'port_entry', 'port_entry_code',
#        'port_entry_lat', 'port_entry_lon', 'shipping_port',
#        'shipping_port_code', 'shipping_port_lar', 'shipping_port_lon'],
#       dtype='object')

# %%
hi = hk_scans_per_donor.loc[hk_scans_per_donor['donor'] != 'unknown'] 

alt.Chart("https://raw.githubusercontent.com/ers6/ia_bols/main/scan-center-counts/hongkong-known-donor-scans.csv").mark_line().encode(
    x='month_year:T',
    y='scandate:Q',
    color='donor:N',
    tooltip= ['donor:N']
).interactive()
# Out:
# alt.Chart(...)
